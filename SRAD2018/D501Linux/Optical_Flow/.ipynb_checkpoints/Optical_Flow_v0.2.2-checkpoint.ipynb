# %%
1+1
# Out:
# 2

# %%
import os
import numpy as np
import pandas as pd
from six.moves import cPickle
import PIL
import matplotlib.pyplot as plt
from matplotlib import cm
import time
import multiprocessing
import random
import sklearn
from sklearn import metrics
import seaborn as sns
import cv2
import skimage
from skimage import restoration
import copy
import seaborn as sns

# %%
raw_RAD_id_list = os.listdir('/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/')
print(len(raw_RAD_id_list))
RAD_id_list = raw_RAD_id_list
# Out:
# 15000

# %%
RAD_id_submit_list = os.listdir("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_Test_2/")
print(len(RAD_id_submit_list))
# Out:
# 8000

# %%
image_size = 64
nt = 4 # number of timesteps used for sequences in training
image_scalar = 80
vmin = -1
vmax = 0.6 * image_scalar
step_size = 5

# %%
# params for ShiTomasi corner detection
feature_params = dict( maxCorners = 100,
                       qualityLevel = 0.3,
                       minDistance = 7,
                       blockSize = 7 )

# Parameters for lucas kanade optical flow
lk_params = dict( winSize  = (15,15),
                  maxLevel = 2,
                  criteria = (cv2.TERM_CRITERIA_EPS | cv2.TERM_CRITERIA_COUNT, 10, 0.03))

color = [255, 255, 255]

# %%
a = np.array(PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png" % (RAD_id, RAD_id, i + 0)))

# %%
a.mean()
# Out:
# 254.97956980251075

# %%
b = np.array(PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_submit/SRAD2018_Neutrino_Optical_Flow_v0.2.1.1_18.10.06.01.55/%s/%s_f%03d.png" % (RAD_id_submit_list[0], RAD_id_submit_list[0], 1)))

# %%
b.mean()
# Out:
# 252.13433811020673

# %%
for counter, RAD_id in enumerate(RAD_id_list[:50]):
    move_list = []
    temp_matrix_list = []
    print(RAD_id)
    for i in range(52, 55, 1):
#     for i in range(0, 60, 5):
#     for i in range(0, 5, 5):
        temp_matrix_old = np.array(PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png" % (RAD_id, RAD_id, i + 0))).astype(np.uint8)
        temp_matrix_new = np.array(PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png" % (RAD_id, RAD_id, i + step_size))).astype(np.uint8)
        temp_matrix_old = np.where(temp_matrix_old==255, 0, temp_matrix_old)
        temp_matrix_new = np.where(temp_matrix_new==255, 0, temp_matrix_new)
        temp_matrix_list.append(temp_matrix_new)
#         plt.imshow(temp_matrix_old, cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
#         plt.show()
#         plt.imshow(temp_matrix_new, cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
#         plt.show()
        
        p0 = cv2.goodFeaturesToTrack(temp_matrix_old, mask = None, **feature_params)
        # Create a mask image for drawing purposes
        mask = np.zeros_like(temp_matrix_old)

        # calculate optical flow
        p1, st, err = cv2.calcOpticalFlowPyrLK(temp_matrix_old, temp_matrix_new, p0, None, **lk_params)

        # Select good points
        good_new = p1[st==1]
        good_old = p0[st==1]
        
        move = (good_new - good_old).mean(axis=0)
        move_list.append(move)
        
        # draw the tracks
        for j,(new,old) in enumerate(zip(good_new,good_old)):
            a,b = new.ravel()
            c,d = old.ravel()
            mask = cv2.line(mask, (a,b),(c,d), color, 2)
            img = copy.deepcopy(temp_matrix_new)
            img = cv2.circle(img,(a,b),3,color,-1)
        img = cv2.add(img,mask)
        
#         print(i, i+5)
#         print(move)
#         plt.imshow(img, cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
#         plt.show()
        
#         H = np.float32([[1,0,move[0]], [0,1,move[1]]])
#         res = cv2.warpAffine(img, H, (501, 501))
#         plt.imshow(res, cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
#         plt.show()
    move_list = np.array(move_list)
    move = move_list.mean(axis=0)
    for i in range(len(temp_matrix_list)):
        k = (len(temp_matrix_list) - 1 - i)
        H = np.float32([[1,0,k*move[0]], [0,1,k*move[1]]])
        temp_matrix_list[i] = cv2.warpAffine(temp_matrix_list[i], H, (501, 501))
        
    temp_matrix_list = np.array(temp_matrix_list)
    temp_matrix = temp_matrix_list.mean(axis=0)
    H = np.float32([[1,0,move[0]], [0,1,move[1]]])
    res = cv2.warpAffine(temp_matrix, H, (501, 501))
#     plt.imshow(res, cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
#     plt.show()
#     plt.imshow(temp_matrix_new, cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
#     plt.show()
# Out:
# RAD_436482474222544
# RAD_326482464239548
# RAD_426382464232542
# RAD_256582464212538
# RAD_416382474232536
# RAD_446482464229537
# RAD_206582464222546
# RAD_466382464212541
# RAD_496482474232542
# RAD_336482464232533
# RAD_466582464222547
# RAD_336582474229546
# RAD_496382464219531
# RAD_486382464212548
# RAD_256482474239552
# RAD_376382464222540
# RAD_296482464232543
# RAD_296582474222537
# RAD_346482464229534
# RAD_446382464219545
# RAD_386582474222532
# RAD_236482464222542
# RAD_306382464229539
# RAD_236482464229542
# RAD_426582474222545
# RAD_426582474222551
# RAD_356582464229531
# RAD_486582464229549
# RAD_266482464229547
# RAD_476482474229534
# RAD_486382464229548
# RAD_436382474232551
# /home/hadoop/.local/lib/python3.5/site-packages/ipykernel_launcher.py:29: RuntimeWarning: Mean of empty slice.
# /home/hadoop/.local/lib/python3.5/site-packages/numpy/core/_methods.py:73: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-7-506fb0452d8e> in <module>()
#      21
#      22         # calculate optical flow
# ---> 23         p1, st, err = cv2.calcOpticalFlowPyrLK(temp_matrix_old, temp_matrix_new, p0, None, **lk_params)
#      24
#      25         # Select good points
#
# error: OpenCV(3.4.2) /io/opencv/modules/video/src/lkpyramid.cpp:1244: error: (-215:Assertion failed) (npoints = prevPtsMat.checkVector(2, 5, true)) >= 0 in function 'calc'

# %%
p0 = [None]

# %%
try:
    len(p0)
except:
    print('e')

# %%
p0

# %%
def predict(RAD_id, path='/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train'):
    mean_list = []
    for i in range(31):
        temp = np.array(PIL.Image.open('%s/%s/%s_%03d.png' % (path, RAD_id, RAD_id, i))).astype(np.uint8)
        temp = np.where(temp==255, 0, temp)
        mean_list.append(temp.ravel().mean())
    mean_list = np.array(mean_list)
    if mean_list.mean() < 0.5:
        return [temp] * 6
    
    move_list = []
    temp_matrix_list = []
#     print(RAD_id)
    for i in range(20, 26, 1):
#     for i in range(20, 26, 1):
#     for i in range(0, 60, 5):
#     for i in range(0, 5, 5):
        temp_matrix_old = np.array(PIL.Image.open("%s/%s/%s_%03d.png" % (path, RAD_id, RAD_id, i + 0))).astype(np.uint8)
        temp_matrix_new = np.array(PIL.Image.open("%s/%s/%s_%03d.png" % (path, RAD_id, RAD_id, i + step_size))).astype(np.uint8)
        temp_matrix_old = np.where(temp_matrix_old==255, 0, temp_matrix_old)
        temp_matrix_new = np.where(temp_matrix_new==255, 0, temp_matrix_new)
        temp_matrix_list.append(temp_matrix_new)
#         plt.imshow(temp_matrix_old, cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
#         plt.show()
#         plt.imshow(temp_matrix_new, cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
#         plt.show()
        
        p0 = cv2.goodFeaturesToTrack(temp_matrix_old, mask = None, **feature_params)
        
        try:
            len(p0)
        except:
            return [temp] * 6
        
        # Create a mask image for drawing purposes
        mask = np.zeros_like(temp_matrix_old)

        # calculate optical flow
        p1, st, err = cv2.calcOpticalFlowPyrLK(temp_matrix_old, temp_matrix_new, p0, None, **lk_params)

        # Select good points
        good_new = p1[st==1]
        good_old = p0[st==1]
        
        move = (good_new - good_old).mean(axis=0)
        move_list.append(move)
        
#         # draw the tracks
#         for j,(new,old) in enumerate(zip(good_new,good_old)):
#             a,b = new.ravel()
#             c,d = old.ravel()
#             mask = cv2.line(mask, (a,b),(c,d), color, 2)
#             img = copy.deepcopy(temp_matrix_new)
#             img = cv2.circle(img,(a,b),3,color,-1)
#         img = cv2.add(img,mask)
        
#         print(i, i+step_size)
#         print(move)
#         plt.imshow(img, cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
#         plt.show()
        
#         H = np.float32([[1,0,move[0]], [0,1,move[1]]])
#         res = cv2.warpAffine(img, H, (501, 501))
#         plt.imshow(res, cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
#         plt.show()
    move_list = np.array(move_list)
    move = move_list.mean(axis=0)
    for i in range(len(temp_matrix_list)):
        k = (len(temp_matrix_list) - 1 - i)
        H = np.float32([[1,0,k*move[0]], [0,1,k*move[1]]])
        temp_matrix_list[i] = cv2.warpAffine(temp_matrix_list[i], H, (501, 501))
        
    temp_matrix_list = np.array(temp_matrix_list)
    temp_matrix = temp_matrix_list.mean(axis=0)
    H = np.float32([[1,0,move[0]], [0,1,move[1]]])
    res = cv2.warpAffine(temp_matrix, H, (501, 501))
#     plt.imshow(res, cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
#     plt.show()
#     plt.imshow(temp_matrix_new, cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
#     plt.show()
    
    ans_list = []
    for i in range(1, 7):
        k = i * 1
        H = np.float32([[1,0,k*move[0]], [0,1,k*move[1]]])
        res = cv2.warpAffine(temp_matrix_new, H, (501, 501))
        ans_list.append(res)
    return ans_list

# %%
start_time = time.time()
print(time.strftime("start time: %Y-%m-%d %H:%M:%S", time.localtime()))
model_abs_loss = []
model_sqr_loss = []
last_frame_abs_loss = []
last_frame_sqr_loss = []
for RAD_id_counter, RAD_id in enumerate(RAD_id_list[:100]):
    x_last = np.array(PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png" % (RAD_id, RAD_id, 30))).astype(np.uint8)
    x_last = np.where(x_last==255, 0, x_last)
    y_true_last = np.array(PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png" % (RAD_id, RAD_id, 60))).astype(np.uint8)
    y_true_last = np.where(y_true_last==255, 0, y_true_last)
    y_pred_last = predict(RAD_id)[-1]
#     plt.imshow(x_last, cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
#     plt.show()
#     plt.imshow(y_pred_last, cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
#     plt.show()
    last_frame_abs_loss.append(sklearn.metrics.mean_absolute_error(y_true_last.astype(np.int), x_last.astype(np.int)))
    model_abs_loss.append(sklearn.metrics.mean_absolute_error(y_true_last.astype(np.int), y_pred_last.astype(np.int)))
    last_frame_sqr_loss.append(sklearn.metrics.mean_squared_error(y_true_last.astype(np.int), x_last.astype(np.int)))
    model_sqr_loss.append(sklearn.metrics.mean_squared_error(y_true_last.astype(np.int), y_pred_last.astype(np.int)))
    if RAD_id_counter % 10 == 0:
        print('RAD_id_counter=%5d\t\tIt takes %.2f' % (RAD_id_counter, time.time() - start_time))
model_abs_loss = np.array(model_abs_loss)
last_frame_abs_loss = np.array(last_frame_abs_loss)
model_sqr_loss = np.array(model_sqr_loss)
last_frame_sqr_loss = np.array(last_frame_sqr_loss)
print('     model_abs_loss=%.7f' % model_abs_loss.mean())
print('last_frame_abs_loss=%.7f' % last_frame_abs_loss.mean())
print('     model_sqr_loss=%.7f' % model_sqr_loss.mean())
print('last_frame_sqr_loss=%.7f' % last_frame_sqr_loss.mean())
print(time.strftime('It took  %H:%M:%S', time.gmtime(time.time() - start_time)))
print(time.strftime("end time: %Y-%m-%d %H:%M:%S", time.localtime()))
# Out:
# start time: 2018-10-07 20:45:24
# RAD_id_counter=    0		It takes 0.11
# RAD_id_counter=   10		It takes 0.64
# RAD_id_counter=   20		It takes 1.30
# RAD_id_counter=   30		It takes 2.04
# RAD_id_counter=   40		It takes 2.71
# RAD_id_counter=   50		It takes 3.37
# RAD_id_counter=   60		It takes 4.02
# RAD_id_counter=   70		It takes 4.85
# RAD_id_counter=   80		It takes 5.47
# RAD_id_counter=   90		It takes 6.32
#      model_abs_loss=1.8744206
# last_frame_abs_loss=1.9779436
#      model_sqr_loss=38.1972909
# last_frame_sqr_loss=40.9361165
# It took  00:00:06
# end time: 2018-10-07 20:45:31

# %%
print('     model_abs_loss=%.7f' % model_abs_loss.mean())
print('last_frame_abs_loss=%.7f' % last_frame_abs_loss.mean())
print('     model_sqr_loss=%.7f' % model_sqr_loss.mean())
print('last_frame_sqr_loss=%.7f' % last_frame_sqr_loss.mean())

plt.imshow(x_last, cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
plt.show()

plt.imshow(y_pred_last, cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
plt.show()

plt.imshow(y_true_last, cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
plt.show()
# Out:
#      model_abs_loss=1.8744206
# last_frame_abs_loss=1.9779436
#      model_sqr_loss=38.1972909
# last_frame_sqr_loss=40.9361165

# %%
version = 'SRAD2018_Neutrino_Optical_Flow_v0.2.2.1_18.10.07.09.22'

# %%
print('version=%s' % version)
start_time = time.time()
print(time.strftime("start time: %Y-%m-%d %H:%M:%S", time.localtime()))
for RAD_id_counter, RAD_id in enumerate(RAD_id_submit_list):
    if not os.path.exists("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_submit/%s/%s" % (version, RAD_id)):
        os.makedirs("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_submit/%s/%s" % (version, RAD_id))
    result_list = predict(RAD_id, path='/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_Test_2')
    for i in range(6):
        result = result_list[i]
        result = result.astype(np.uint8)
        result = np.where(result==0, 255, result)
        result = PIL.Image.fromarray(result)
        result.save("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_submit/%s/%s/%s_f%03d.png" % (version, RAD_id, RAD_id, i + 1))
    if RAD_id_counter % 10 == 0:
        print('RAD_id_counter=%5d\t\tIt takes %.2f' % (RAD_id_counter, time.time() - start_time))
print(time.strftime('It took  %H:%M:%S', time.gmtime(time.time() - start_time)))
print(time.strftime("end time: %Y-%m-%d %H:%M:%S", time.localtime()))
# Out:
# version=SRAD2018_Neutrino_Optical_Flow_v0.2.2.1_18.10.07.09.22
# start time: 2018-10-07 09:25:40
# RAD_id_counter=    0		It takes 0.06
# RAD_id_counter=   10		It takes 0.81
# RAD_id_counter=   20		It takes 2.25
# RAD_id_counter=   30		It takes 3.24
# RAD_id_counter=   40		It takes 4.10
# RAD_id_counter=   50		It takes 4.83
# RAD_id_counter=   60		It takes 5.89
# RAD_id_counter=   70		It takes 6.90
# RAD_id_counter=   80		It takes 7.62
# RAD_id_counter=   90		It takes 8.35
# RAD_id_counter=  100		It takes 9.11
# RAD_id_counter=  110		It takes 9.95
# RAD_id_counter=  120		It takes 10.97
# RAD_id_counter=  130		It takes 11.71
# RAD_id_counter=  140		It takes 12.90
# RAD_id_counter=  150		It takes 13.71
# RAD_id_counter=  160		It takes 15.07
# RAD_id_counter=  170		It takes 15.99
# RAD_id_counter=  180		It takes 16.97
# RAD_id_counter=  190		It takes 18.02
# RAD_id_counter=  200		It takes 18.96
# RAD_id_counter=  210		It takes 19.82
# RAD_id_counter=  220		It takes 20.69
# RAD_id_counter=  230		It takes 21.52
# RAD_id_counter=  240		It takes 22.29
# RAD_id_counter=  250		It takes 23.25
# RAD_id_counter=  260		It takes 24.28
# RAD_id_counter=  270		It takes 25.24
# RAD_id_counter=  280		It takes 26.36
# RAD_id_counter=  290		It takes 27.19
# RAD_id_counter=  300		It takes 28.09
# RAD_id_counter=  310		It takes 28.70
# RAD_id_counter=  320		It takes 29.62
# RAD_id_counter=  330		It takes 30.66
# RAD_id_counter=  340		It takes 31.55
# RAD_id_counter=  350		It takes 32.72
# RAD_id_counter=  360		It takes 33.79
# RAD_id_counter=  370		It takes 34.55
# RAD_id_counter=  380		It takes 35.39
# RAD_id_counter=  390		It takes 36.22
# RAD_id_counter=  400		It takes 37.08
# RAD_id_counter=  410		It takes 38.16
# RAD_id_counter=  420		It takes 39.25
# RAD_id_counter=  430		It takes 40.20
# RAD_id_counter=  440		It takes 41.17
# RAD_id_counter=  450		It takes 42.42
# RAD_id_counter=  460		It takes 43.46
# RAD_id_counter=  470		It takes 44.35
# RAD_id_counter=  480		It takes 45.70
# RAD_id_counter=  490		It takes 46.66
# RAD_id_counter=  500		It takes 47.71
# RAD_id_counter=  510		It takes 48.91
# RAD_id_counter=  520		It takes 50.04
# RAD_id_counter=  530		It takes 51.39
# RAD_id_counter=  540		It takes 52.47
# RAD_id_counter=  550		It takes 53.48
# RAD_id_counter=  560		It takes 54.15
# RAD_id_counter=  570		It takes 55.45
# RAD_id_counter=  580		It takes 56.51
# RAD_id_counter=  590		It takes 57.26
# RAD_id_counter=  600		It takes 58.32
# RAD_id_counter=  610		It takes 59.28
# RAD_id_counter=  620		It takes 60.17
# RAD_id_counter=  630		It takes 61.11
# RAD_id_counter=  640		It takes 62.15
# RAD_id_counter=  650		It takes 63.01
# RAD_id_counter=  660		It takes 63.73
# RAD_id_counter=  670		It takes 64.84
# RAD_id_counter=  680		It takes 65.92
# RAD_id_counter=  690		It takes 66.85
# RAD_id_counter=  700		It takes 67.78
# RAD_id_counter=  710		It takes 68.75
# RAD_id_counter=  720		It takes 69.79
# RAD_id_counter=  730		It takes 71.34
# RAD_id_counter=  740		It takes 72.25
# RAD_id_counter=  750		It takes 73.59
# RAD_id_counter=  760		It takes 74.68
# RAD_id_counter=  770		It takes 75.67
# RAD_id_counter=  780		It takes 76.43
# RAD_id_counter=  790		It takes 77.37
# RAD_id_counter=  800		It takes 78.52
# RAD_id_counter=  810		It takes 79.45
# RAD_id_counter=  820		It takes 80.48
# RAD_id_counter=  830		It takes 81.54
# RAD_id_counter=  840		It takes 82.49
# RAD_id_counter=  850		It takes 83.25
# RAD_id_counter=  860		It takes 84.46
# RAD_id_counter=  870		It takes 85.46
# RAD_id_counter=  880		It takes 86.53
# RAD_id_counter=  890		It takes 87.49
# RAD_id_counter=  900		It takes 88.55
# RAD_id_counter=  910		It takes 89.56
# RAD_id_counter=  920		It takes 90.33
# RAD_id_counter=  930		It takes 91.09
# RAD_id_counter=  940		It takes 91.89
# RAD_id_counter=  950		It takes 93.00
# RAD_id_counter=  960		It takes 93.75
# RAD_id_counter=  970		It takes 94.91
# RAD_id_counter=  980		It takes 95.69
# RAD_id_counter=  990		It takes 96.71
# RAD_id_counter= 1000		It takes 97.69
# RAD_id_counter= 1010		It takes 98.59
# RAD_id_counter= 1020		It takes 99.73
# RAD_id_counter= 1030		It takes 100.56
# RAD_id_counter= 1040		It takes 101.47
# RAD_id_counter= 1050		It takes 102.27
# RAD_id_counter= 1060		It takes 103.01
# RAD_id_counter= 1070		It takes 103.76
# RAD_id_counter= 1080		It takes 104.54
# RAD_id_counter= 1090		It takes 105.68
# RAD_id_counter= 1100		It takes 106.69
# RAD_id_counter= 1110		It takes 107.47
# RAD_id_counter= 1120		It takes 108.41
# RAD_id_counter= 1130		It takes 109.33
# RAD_id_counter= 1140		It takes 110.27
# RAD_id_counter= 1150		It takes 111.61
# RAD_id_counter= 1160		It takes 112.58
# RAD_id_counter= 1170		It takes 113.37
# RAD_id_counter= 1180		It takes 114.20
# RAD_id_counter= 1190		It takes 114.81
# RAD_id_counter= 1200		It takes 115.59
# RAD_id_counter= 1210		It takes 116.45
# RAD_id_counter= 1220		It takes 117.66
# RAD_id_counter= 1230		It takes 118.50
# RAD_id_counter= 1240		It takes 119.34
# RAD_id_counter= 1250		It takes 120.19
# RAD_id_counter= 1260		It takes 121.21
# RAD_id_counter= 1270		It takes 121.79
# RAD_id_counter= 1280		It takes 122.78
# RAD_id_counter= 1290		It takes 123.89
# RAD_id_counter= 1300		It takes 124.79
# RAD_id_counter= 1310		It takes 125.89
# RAD_id_counter= 1320		It takes 126.64
# RAD_id_counter= 1330		It takes 127.50
# RAD_id_counter= 1340		It takes 128.29
# RAD_id_counter= 1350		It takes 129.37
# RAD_id_counter= 1360		It takes 130.54
# RAD_id_counter= 1370		It takes 131.31
# RAD_id_counter= 1380		It takes 132.37
# RAD_id_counter= 1390		It takes 133.49
# RAD_id_counter= 1400		It takes 134.45
# RAD_id_counter= 1410		It takes 135.35
# RAD_id_counter= 1420		It takes 136.00
# RAD_id_counter= 1430		It takes 137.09
# RAD_id_counter= 1440		It takes 138.16
# RAD_id_counter= 1450		It takes 138.86
# RAD_id_counter= 1460		It takes 139.88
# RAD_id_counter= 1470		It takes 140.74
# RAD_id_counter= 1480		It takes 141.63
# RAD_id_counter= 1490		It takes 142.67
# RAD_id_counter= 1500		It takes 143.56
# RAD_id_counter= 1510		It takes 144.38
# RAD_id_counter= 1520		It takes 145.21
# RAD_id_counter= 1530		It takes 146.03
# RAD_id_counter= 1540		It takes 147.07
# RAD_id_counter= 1550		It takes 147.90
# RAD_id_counter= 1560		It takes 148.86
# RAD_id_counter= 1570		It takes 149.79
# RAD_id_counter= 1580		It takes 150.88
# RAD_id_counter= 1590		It takes 151.83
# RAD_id_counter= 1600		It takes 152.72
# RAD_id_counter= 1610		It takes 153.75
# RAD_id_counter= 1620		It takes 154.83
# RAD_id_counter= 1630		It takes 155.95
# RAD_id_counter= 1640		It takes 156.98
# RAD_id_counter= 1650		It takes 158.22
# RAD_id_counter= 1660		It takes 159.41
# RAD_id_counter= 1670		It takes 160.14
# RAD_id_counter= 1680		It takes 161.15
# RAD_id_counter= 1690		It takes 161.93
# RAD_id_counter= 1700		It takes 162.70
# RAD_id_counter= 1710		It takes 164.03
# RAD_id_counter= 1720		It takes 165.11
# RAD_id_counter= 1730		It takes 166.21
# RAD_id_counter= 1740		It takes 167.16
# RAD_id_counter= 1750		It takes 168.37
# RAD_id_counter= 1760		It takes 169.25
# RAD_id_counter= 1770		It takes 170.26
# /home/hadoop/.local/lib/python3.5/site-packages/ipykernel_launcher.py:45: RuntimeWarning: Mean of empty slice.
# /home/hadoop/.local/lib/python3.5/site-packages/numpy/core/_methods.py:73: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# RAD_id_counter= 1780		It takes 170.96
# RAD_id_counter= 1790		It takes 172.13
# RAD_id_counter= 1800		It takes 173.12
# RAD_id_counter= 1810		It takes 174.22
# RAD_id_counter= 1820		It takes 175.11
# RAD_id_counter= 1830		It takes 176.37
# RAD_id_counter= 1840		It takes 177.27
# RAD_id_counter= 1850		It takes 178.22
# RAD_id_counter= 1860		It takes 179.10
# RAD_id_counter= 1870		It takes 180.14
# RAD_id_counter= 1880		It takes 181.20
# RAD_id_counter= 1890		It takes 181.98
# RAD_id_counter= 1900		It takes 183.10
# RAD_id_counter= 1910		It takes 183.90
# RAD_id_counter= 1920		It takes 184.92
# RAD_id_counter= 1930		It takes 185.89
# RAD_id_counter= 1940		It takes 186.60
# RAD_id_counter= 1950		It takes 187.36
# RAD_id_counter= 1960		It takes 188.52
# RAD_id_counter= 1970		It takes 189.56
# RAD_id_counter= 1980		It takes 190.55
# RAD_id_counter= 1990		It takes 191.47
# RAD_id_counter= 2000		It takes 192.35
# RAD_id_counter= 2010		It takes 193.16
# RAD_id_counter= 2020		It takes 194.15
# RAD_id_counter= 2030		It takes 195.12
# RAD_id_counter= 2040		It takes 195.85
# RAD_id_counter= 2050		It takes 196.88
# RAD_id_counter= 2060		It takes 197.95
# RAD_id_counter= 2070		It takes 199.08
# RAD_id_counter= 2080		It takes 200.09
# RAD_id_counter= 2090		It takes 200.92
# RAD_id_counter= 2100		It takes 201.61
# RAD_id_counter= 2110		It takes 202.53
# RAD_id_counter= 2120		It takes 203.66
# RAD_id_counter= 2130		It takes 204.69
# RAD_id_counter= 2140		It takes 205.60
# RAD_id_counter= 2150		It takes 206.44
# RAD_id_counter= 2160		It takes 207.50
# RAD_id_counter= 2170		It takes 208.17
# RAD_id_counter= 2180		It takes 209.00
# RAD_id_counter= 2190		It takes 209.80
# RAD_id_counter= 2200		It takes 210.99
# RAD_id_counter= 2210		It takes 211.76
# RAD_id_counter= 2220		It takes 212.38
# RAD_id_counter= 2230		It takes 213.14
# RAD_id_counter= 2240		It takes 213.87
# RAD_id_counter= 2250		It takes 214.47
# RAD_id_counter= 2260		It takes 215.22
# RAD_id_counter= 2270		It takes 216.19
# RAD_id_counter= 2280		It takes 217.21
# RAD_id_counter= 2290		It takes 218.27
# RAD_id_counter= 2300		It takes 219.26
# RAD_id_counter= 2310		It takes 220.48
# RAD_id_counter= 2320		It takes 221.44
# RAD_id_counter= 2330		It takes 222.30
# RAD_id_counter= 2340		It takes 222.99
# RAD_id_counter= 2350		It takes 224.07
# RAD_id_counter= 2360		It takes 225.24
# RAD_id_counter= 2370		It takes 226.17
# RAD_id_counter= 2380		It takes 227.04
# RAD_id_counter= 2390		It takes 227.74
# RAD_id_counter= 2400		It takes 228.74
# RAD_id_counter= 2410		It takes 229.77
# RAD_id_counter= 2420		It takes 230.67
# RAD_id_counter= 2430		It takes 231.90
# RAD_id_counter= 2440		It takes 232.87
# RAD_id_counter= 2450		It takes 233.97
# RAD_id_counter= 2460		It takes 235.04
# RAD_id_counter= 2470		It takes 236.22
# RAD_id_counter= 2480		It takes 237.05
# RAD_id_counter= 2490		It takes 238.00
# RAD_id_counter= 2500		It takes 238.85
# RAD_id_counter= 2510		It takes 239.86
# RAD_id_counter= 2520		It takes 240.67
# RAD_id_counter= 2530		It takes 241.66
# RAD_id_counter= 2540		It takes 242.55
# RAD_id_counter= 2550		It takes 243.45
# RAD_id_counter= 2560		It takes 244.20
# RAD_id_counter= 2570		It takes 245.31
# RAD_id_counter= 2580		It takes 246.53
# RAD_id_counter= 2590		It takes 247.34
# RAD_id_counter= 2600		It takes 248.40
# RAD_id_counter= 2610		It takes 249.23
# RAD_id_counter= 2620		It takes 250.18
# RAD_id_counter= 2630		It takes 251.02
# RAD_id_counter= 2640		It takes 251.92
# RAD_id_counter= 2650		It takes 253.06
# RAD_id_counter= 2660		It takes 253.80
# RAD_id_counter= 2670		It takes 254.84
# RAD_id_counter= 2680		It takes 255.65
# RAD_id_counter= 2690		It takes 256.63
# RAD_id_counter= 2700		It takes 257.42
# RAD_id_counter= 2710		It takes 258.12
# RAD_id_counter= 2720		It takes 259.07
# RAD_id_counter= 2730		It takes 259.88
# RAD_id_counter= 2740		It takes 260.69
# RAD_id_counter= 2750		It takes 261.46
# RAD_id_counter= 2760		It takes 262.14
# RAD_id_counter= 2770		It takes 263.16
# RAD_id_counter= 2780		It takes 264.17
# RAD_id_counter= 2790		It takes 265.29
# RAD_id_counter= 2800		It takes 266.26
# RAD_id_counter= 2810		It takes 267.20
# RAD_id_counter= 2820		It takes 268.28
# RAD_id_counter= 2830		It takes 269.19
# RAD_id_counter= 2840		It takes 270.08
# RAD_id_counter= 2850		It takes 270.90
# RAD_id_counter= 2860		It takes 272.07
# RAD_id_counter= 2870		It takes 273.01
# RAD_id_counter= 2880		It takes 273.96
# RAD_id_counter= 2890		It takes 274.96
# RAD_id_counter= 2900		It takes 275.87
# RAD_id_counter= 2910		It takes 276.46
# RAD_id_counter= 2920		It takes 277.57
# RAD_id_counter= 2930		It takes 278.35
# RAD_id_counter= 2940		It takes 279.58
# RAD_id_counter= 2950		It takes 280.45
# RAD_id_counter= 2960		It takes 281.59
# RAD_id_counter= 2970		It takes 282.27
# RAD_id_counter= 2980		It takes 283.11
# RAD_id_counter= 2990		It takes 283.94
# RAD_id_counter= 3000		It takes 284.99
# RAD_id_counter= 3010		It takes 286.11
# RAD_id_counter= 3020		It takes 287.07
# RAD_id_counter= 3030		It takes 287.94
# RAD_id_counter= 3040		It takes 288.78
# RAD_id_counter= 3050		It takes 289.42
# RAD_id_counter= 3060		It takes 290.63
# RAD_id_counter= 3070		It takes 291.65
# RAD_id_counter= 3080		It takes 292.51
# RAD_id_counter= 3090		It takes 293.29
# RAD_id_counter= 3100		It takes 294.35
# RAD_id_counter= 3110		It takes 295.36
# RAD_id_counter= 3120		It takes 296.13
# RAD_id_counter= 3130		It takes 297.10
# RAD_id_counter= 3140		It takes 297.97
# RAD_id_counter= 3150		It takes 299.12
# RAD_id_counter= 3160		It takes 300.09
# RAD_id_counter= 3170		It takes 301.19
# RAD_id_counter= 3180		It takes 301.94
# RAD_id_counter= 3190		It takes 302.89
# RAD_id_counter= 3200		It takes 303.90
# RAD_id_counter= 3210		It takes 304.70
# RAD_id_counter= 3220		It takes 305.80
# RAD_id_counter= 3230		It takes 307.07
# RAD_id_counter= 3240		It takes 308.23
# RAD_id_counter= 3250		It takes 308.99
# RAD_id_counter= 3260		It takes 309.92
# RAD_id_counter= 3270		It takes 310.53
# RAD_id_counter= 3280		It takes 311.43
# RAD_id_counter= 3290		It takes 312.13
# RAD_id_counter= 3300		It takes 313.05
# RAD_id_counter= 3310		It takes 314.00
# RAD_id_counter= 3320		It takes 314.98
# RAD_id_counter= 3330		It takes 315.87
# RAD_id_counter= 3340		It takes 316.83
# RAD_id_counter= 3350		It takes 317.87
# RAD_id_counter= 3360		It takes 318.88
# RAD_id_counter= 3370		It takes 319.77
# RAD_id_counter= 3380		It takes 320.71
# RAD_id_counter= 3390		It takes 321.77
# RAD_id_counter= 3400		It takes 322.82
# RAD_id_counter= 3410		It takes 323.96
# RAD_id_counter= 3420		It takes 324.81
# RAD_id_counter= 3430		It takes 325.91
# RAD_id_counter= 3440		It takes 326.66
# RAD_id_counter= 3450		It takes 327.82
# RAD_id_counter= 3460		It takes 328.58
# RAD_id_counter= 3470		It takes 329.31
# RAD_id_counter= 3480		It takes 330.27
# RAD_id_counter= 3490		It takes 331.49
# RAD_id_counter= 3500		It takes 332.55
# RAD_id_counter= 3510		It takes 333.63
# RAD_id_counter= 3520		It takes 334.55
# RAD_id_counter= 3530		It takes 335.39
# RAD_id_counter= 3540		It takes 336.51
# RAD_id_counter= 3550		It takes 337.70
# RAD_id_counter= 3560		It takes 338.88
# RAD_id_counter= 3570		It takes 339.76
# RAD_id_counter= 3580		It takes 340.72
# RAD_id_counter= 3590		It takes 341.68
# RAD_id_counter= 3600		It takes 342.49
# RAD_id_counter= 3610		It takes 343.50
# RAD_id_counter= 3620		It takes 344.74
# RAD_id_counter= 3630		It takes 345.91
# RAD_id_counter= 3640		It takes 347.10
# RAD_id_counter= 3650		It takes 348.11
# RAD_id_counter= 3660		It takes 348.68
# RAD_id_counter= 3670		It takes 349.76
# RAD_id_counter= 3680		It takes 350.70
# RAD_id_counter= 3690		It takes 351.93
# RAD_id_counter= 3700		It takes 352.70
# RAD_id_counter= 3710		It takes 353.67
# RAD_id_counter= 3720		It takes 354.52
# RAD_id_counter= 3730		It takes 355.79
# RAD_id_counter= 3740		It takes 356.87
# RAD_id_counter= 3750		It takes 357.70
# RAD_id_counter= 3760		It takes 358.93
# RAD_id_counter= 3770		It takes 360.01
# RAD_id_counter= 3780		It takes 360.70
# RAD_id_counter= 3790		It takes 361.67
# RAD_id_counter= 3800		It takes 362.28
# RAD_id_counter= 3810		It takes 363.31
# RAD_id_counter= 3820		It takes 364.19
# RAD_id_counter= 3830		It takes 365.13
# RAD_id_counter= 3840		It takes 366.16
# RAD_id_counter= 3850		It takes 366.95
# RAD_id_counter= 3860		It takes 367.83
# RAD_id_counter= 3870		It takes 368.86
# RAD_id_counter= 3880		It takes 369.92
# RAD_id_counter= 3890		It takes 371.13
# RAD_id_counter= 3900		It takes 372.24
# RAD_id_counter= 3910		It takes 373.49
# RAD_id_counter= 3920		It takes 374.44
# RAD_id_counter= 3930		It takes 375.44
# RAD_id_counter= 3940		It takes 376.35
# RAD_id_counter= 3950		It takes 377.29
# RAD_id_counter= 3960		It takes 378.55
# RAD_id_counter= 3970		It takes 379.43
# RAD_id_counter= 3980		It takes 380.39
# RAD_id_counter= 3990		It takes 381.55
# RAD_id_counter= 4000		It takes 382.47
# RAD_id_counter= 4010		It takes 383.55
# RAD_id_counter= 4020		It takes 384.37
# RAD_id_counter= 4030		It takes 385.24
# RAD_id_counter= 4040		It takes 386.07
# RAD_id_counter= 4050		It takes 387.01
# RAD_id_counter= 4060		It takes 387.88
# RAD_id_counter= 4070		It takes 388.83
# RAD_id_counter= 4080		It takes 389.84
# RAD_id_counter= 4090		It takes 390.82
# RAD_id_counter= 4100		It takes 391.65
# RAD_id_counter= 4110		It takes 392.54
# RAD_id_counter= 4120		It takes 393.48
# RAD_id_counter= 4130		It takes 394.85
# RAD_id_counter= 4140		It takes 395.87
# RAD_id_counter= 4150		It takes 397.12
# RAD_id_counter= 4160		It takes 397.88
# RAD_id_counter= 4170		It takes 399.00
# RAD_id_counter= 4180		It takes 399.59
# RAD_id_counter= 4190		It takes 400.58
# RAD_id_counter= 4200		It takes 401.69
# RAD_id_counter= 4210		It takes 402.79
# RAD_id_counter= 4220		It takes 403.72
# RAD_id_counter= 4230		It takes 404.83
# RAD_id_counter= 4240		It takes 405.80
# RAD_id_counter= 4250		It takes 406.57
# RAD_id_counter= 4260		It takes 407.37
# RAD_id_counter= 4270		It takes 408.54
# RAD_id_counter= 4280		It takes 409.12
# RAD_id_counter= 4290		It takes 409.85
# RAD_id_counter= 4300		It takes 411.00
# RAD_id_counter= 4310		It takes 412.09
# RAD_id_counter= 4320		It takes 412.94
# RAD_id_counter= 4330		It takes 414.23
# RAD_id_counter= 4340		It takes 415.48
# RAD_id_counter= 4350		It takes 416.48
# RAD_id_counter= 4360		It takes 417.53
# RAD_id_counter= 4370		It takes 418.64
# RAD_id_counter= 4380		It takes 419.38
# RAD_id_counter= 4390		It takes 420.51
# RAD_id_counter= 4400		It takes 421.49
# RAD_id_counter= 4410		It takes 422.40
# RAD_id_counter= 4420		It takes 423.41
# RAD_id_counter= 4430		It takes 424.35
# RAD_id_counter= 4440		It takes 425.33
# RAD_id_counter= 4450		It takes 426.52
# RAD_id_counter= 4460		It takes 427.36
# RAD_id_counter= 4470		It takes 428.42
# RAD_id_counter= 4480		It takes 429.32
# RAD_id_counter= 4490		It takes 430.28
# RAD_id_counter= 4500		It takes 431.04
# RAD_id_counter= 4510		It takes 431.77
# RAD_id_counter= 4520		It takes 432.63
# RAD_id_counter= 4530		It takes 433.53
# RAD_id_counter= 4540		It takes 434.51
# RAD_id_counter= 4550		It takes 435.58
# RAD_id_counter= 4560		It takes 436.37
# RAD_id_counter= 4570		It takes 437.36
# RAD_id_counter= 4580		It takes 438.44
# RAD_id_counter= 4590		It takes 439.51
# RAD_id_counter= 4600		It takes 440.06
# RAD_id_counter= 4610		It takes 440.92
# RAD_id_counter= 4620		It takes 441.85
# RAD_id_counter= 4630		It takes 443.14
# RAD_id_counter= 4640		It takes 444.20
# RAD_id_counter= 4650		It takes 445.12
# RAD_id_counter= 4660		It takes 445.78
# RAD_id_counter= 4670		It takes 446.91
# RAD_id_counter= 4680		It takes 448.16
# RAD_id_counter= 4690		It takes 448.96
# RAD_id_counter= 4700		It takes 450.06
# RAD_id_counter= 4710		It takes 451.03
# RAD_id_counter= 4720		It takes 452.27
# RAD_id_counter= 4730		It takes 453.30
# RAD_id_counter= 4740		It takes 454.12
# RAD_id_counter= 4750		It takes 455.01
# RAD_id_counter= 4760		It takes 456.16
# RAD_id_counter= 4770		It takes 457.19
# RAD_id_counter= 4780		It takes 457.76
# RAD_id_counter= 4790		It takes 458.85
# RAD_id_counter= 4800		It takes 459.75
# RAD_id_counter= 4810		It takes 460.94
# RAD_id_counter= 4820		It takes 462.10
# RAD_id_counter= 4830		It takes 462.77
# RAD_id_counter= 4840		It takes 463.62
# RAD_id_counter= 4850		It takes 465.01
# RAD_id_counter= 4860		It takes 466.05
# RAD_id_counter= 4870		It takes 466.69
# RAD_id_counter= 4880		It takes 467.70
# RAD_id_counter= 4890		It takes 468.95
# RAD_id_counter= 4900		It takes 469.84
# RAD_id_counter= 4910		It takes 470.98
# RAD_id_counter= 4920		It takes 472.04
# RAD_id_counter= 4930		It takes 472.88
# RAD_id_counter= 4940		It takes 473.59
# RAD_id_counter= 4950		It takes 474.46
# RAD_id_counter= 4960		It takes 475.35
# RAD_id_counter= 4970		It takes 476.10
# RAD_id_counter= 4980		It takes 477.19
# RAD_id_counter= 4990		It takes 478.12
# RAD_id_counter= 5000		It takes 479.09
# RAD_id_counter= 5010		It takes 479.81
# RAD_id_counter= 5020		It takes 480.73
# RAD_id_counter= 5030		It takes 481.87
# RAD_id_counter= 5040		It takes 482.85
# RAD_id_counter= 5050		It takes 483.66
# RAD_id_counter= 5060		It takes 484.46
# RAD_id_counter= 5070		It takes 485.55
# RAD_id_counter= 5080		It takes 486.75
# RAD_id_counter= 5090		It takes 487.63
# RAD_id_counter= 5100		It takes 488.83
# RAD_id_counter= 5110		It takes 489.82
# RAD_id_counter= 5120		It takes 490.80
# RAD_id_counter= 5130		It takes 491.64
# RAD_id_counter= 5140		It takes 492.38
# RAD_id_counter= 5150		It takes 493.35
# RAD_id_counter= 5160		It takes 494.27
# RAD_id_counter= 5170		It takes 495.33
# RAD_id_counter= 5180		It takes 496.02
# RAD_id_counter= 5190		It takes 496.88
# RAD_id_counter= 5200		It takes 497.91
# RAD_id_counter= 5210		It takes 498.81
# RAD_id_counter= 5220		It takes 500.05
# RAD_id_counter= 5230		It takes 500.98
# RAD_id_counter= 5240		It takes 501.95
# RAD_id_counter= 5250		It takes 503.07
# RAD_id_counter= 5260		It takes 504.11
# RAD_id_counter= 5270		It takes 505.00
# RAD_id_counter= 5280		It takes 506.17
# RAD_id_counter= 5290		It takes 506.90
# RAD_id_counter= 5300		It takes 507.79
# RAD_id_counter= 5310		It takes 509.00
# RAD_id_counter= 5320		It takes 509.77
# RAD_id_counter= 5330		It takes 510.64
# RAD_id_counter= 5340		It takes 511.70
# RAD_id_counter= 5350		It takes 512.72
# RAD_id_counter= 5360		It takes 513.48
# RAD_id_counter= 5370		It takes 514.41
# RAD_id_counter= 5380		It takes 515.43
# RAD_id_counter= 5390		It takes 516.29
# RAD_id_counter= 5400		It takes 517.14
# RAD_id_counter= 5410		It takes 518.03
# RAD_id_counter= 5420		It takes 519.17
# RAD_id_counter= 5430		It takes 520.31
# RAD_id_counter= 5440		It takes 521.21
# RAD_id_counter= 5450		It takes 522.14
# RAD_id_counter= 5460		It takes 523.07
# RAD_id_counter= 5470		It takes 523.92
# RAD_id_counter= 5480		It takes 524.76
# RAD_id_counter= 5490		It takes 525.99
# RAD_id_counter= 5500		It takes 527.03
# RAD_id_counter= 5510		It takes 528.12
# RAD_id_counter= 5520		It takes 529.21
# RAD_id_counter= 5530		It takes 529.88
# RAD_id_counter= 5540		It takes 530.86
# RAD_id_counter= 5550		It takes 531.97
# RAD_id_counter= 5560		It takes 532.72
# RAD_id_counter= 5570		It takes 533.43
# RAD_id_counter= 5580		It takes 534.31
# RAD_id_counter= 5590		It takes 535.26
# RAD_id_counter= 5600		It takes 536.11
# RAD_id_counter= 5610		It takes 537.15
# RAD_id_counter= 5620		It takes 538.18
# RAD_id_counter= 5630		It takes 539.13
# RAD_id_counter= 5640		It takes 539.96
# RAD_id_counter= 5650		It takes 540.80
# RAD_id_counter= 5660		It takes 541.67
# RAD_id_counter= 5670		It takes 542.34
# RAD_id_counter= 5680		It takes 543.32
# RAD_id_counter= 5690		It takes 544.01
# RAD_id_counter= 5700		It takes 545.10
# RAD_id_counter= 5710		It takes 546.21
# RAD_id_counter= 5720		It takes 547.46
# RAD_id_counter= 5730		It takes 548.28
# RAD_id_counter= 5740		It takes 549.19
# RAD_id_counter= 5750		It takes 549.81
# RAD_id_counter= 5760		It takes 550.81
# RAD_id_counter= 5770		It takes 551.91
# RAD_id_counter= 5780		It takes 552.71
# RAD_id_counter= 5790		It takes 553.69
# RAD_id_counter= 5800		It takes 554.73
# RAD_id_counter= 5810		It takes 555.66
# RAD_id_counter= 5820		It takes 556.84
# RAD_id_counter= 5830		It takes 557.83
# RAD_id_counter= 5840		It takes 558.65
# RAD_id_counter= 5850		It takes 559.62
# RAD_id_counter= 5860		It takes 560.55
# RAD_id_counter= 5870		It takes 561.48
# RAD_id_counter= 5880		It takes 562.17
# RAD_id_counter= 5890		It takes 563.26
# RAD_id_counter= 5900		It takes 564.27
# RAD_id_counter= 5910		It takes 565.22
# RAD_id_counter= 5920		It takes 566.27
# RAD_id_counter= 5930		It takes 567.08
# RAD_id_counter= 5940		It takes 567.96
# RAD_id_counter= 5950		It takes 569.12
# RAD_id_counter= 5960		It takes 570.09
# RAD_id_counter= 5970		It takes 571.00
# RAD_id_counter= 5980		It takes 572.03
# RAD_id_counter= 5990		It takes 572.84
# RAD_id_counter= 6000		It takes 573.86
# RAD_id_counter= 6010		It takes 575.09
# RAD_id_counter= 6020		It takes 576.12
# RAD_id_counter= 6030		It takes 577.21
# RAD_id_counter= 6040		It takes 578.10
# RAD_id_counter= 6050		It takes 579.25
# RAD_id_counter= 6060		It takes 580.16
# RAD_id_counter= 6070		It takes 581.41
# RAD_id_counter= 6080		It takes 582.27
# RAD_id_counter= 6090		It takes 583.34
# RAD_id_counter= 6100		It takes 584.15
# RAD_id_counter= 6110		It takes 584.98
# RAD_id_counter= 6120		It takes 586.25
# RAD_id_counter= 6130		It takes 587.18
# RAD_id_counter= 6140		It takes 588.19
# RAD_id_counter= 6150		It takes 589.29
# RAD_id_counter= 6160		It takes 590.00
# RAD_id_counter= 6170		It takes 590.67
# RAD_id_counter= 6180		It takes 591.65
# RAD_id_counter= 6190		It takes 592.72
# RAD_id_counter= 6200		It takes 593.61
# RAD_id_counter= 6210		It takes 594.48
# RAD_id_counter= 6220		It takes 595.57
# RAD_id_counter= 6230		It takes 596.39
# RAD_id_counter= 6240		It takes 597.52
# RAD_id_counter= 6250		It takes 598.69
# RAD_id_counter= 6260		It takes 599.74
# RAD_id_counter= 6270		It takes 600.62
# RAD_id_counter= 6280		It takes 601.55
# RAD_id_counter= 6290		It takes 602.39
# RAD_id_counter= 6300		It takes 603.43
# RAD_id_counter= 6310		It takes 604.45
# RAD_id_counter= 6320		It takes 605.13
# RAD_id_counter= 6330		It takes 606.05
# RAD_id_counter= 6340		It takes 607.09
# RAD_id_counter= 6350		It takes 607.79
# RAD_id_counter= 6360		It takes 608.73
# RAD_id_counter= 6370		It takes 609.65
# RAD_id_counter= 6380		It takes 610.65
# RAD_id_counter= 6390		It takes 611.67
# RAD_id_counter= 6400		It takes 612.73
# RAD_id_counter= 6410		It takes 613.85
# RAD_id_counter= 6420		It takes 614.60
# RAD_id_counter= 6430		It takes 615.54
# RAD_id_counter= 6440		It takes 616.55
# RAD_id_counter= 6450		It takes 617.32
# RAD_id_counter= 6460		It takes 618.51
# RAD_id_counter= 6470		It takes 619.53
# RAD_id_counter= 6480		It takes 620.52
# RAD_id_counter= 6490		It takes 621.26
# RAD_id_counter= 6500		It takes 622.17
# RAD_id_counter= 6510		It takes 622.93
# RAD_id_counter= 6520		It takes 623.76
# RAD_id_counter= 6530		It takes 624.61
# RAD_id_counter= 6540		It takes 625.71
# RAD_id_counter= 6550		It takes 626.55
# RAD_id_counter= 6560		It takes 627.74
# RAD_id_counter= 6570		It takes 628.54
# RAD_id_counter= 6580		It takes 629.17
# RAD_id_counter= 6590		It takes 630.06
# RAD_id_counter= 6600		It takes 631.38
# RAD_id_counter= 6610		It takes 632.53
# RAD_id_counter= 6620		It takes 633.50
# RAD_id_counter= 6630		It takes 634.30
# RAD_id_counter= 6640		It takes 635.10
# RAD_id_counter= 6650		It takes 636.24
# RAD_id_counter= 6660		It takes 637.04
# RAD_id_counter= 6670		It takes 638.08
# RAD_id_counter= 6680		It takes 639.01
# RAD_id_counter= 6690		It takes 640.21
# RAD_id_counter= 6700		It takes 641.06
# RAD_id_counter= 6710		It takes 642.53
# RAD_id_counter= 6720		It takes 643.71
# RAD_id_counter= 6730		It takes 644.72
# RAD_id_counter= 6740		It takes 645.54
# RAD_id_counter= 6750		It takes 646.67
# RAD_id_counter= 6760		It takes 647.81
# RAD_id_counter= 6770		It takes 648.71
# RAD_id_counter= 6780		It takes 649.61
# RAD_id_counter= 6790		It takes 650.63
# RAD_id_counter= 6800		It takes 651.45
# RAD_id_counter= 6810		It takes 652.27
# RAD_id_counter= 6820		It takes 653.23
# RAD_id_counter= 6830		It takes 653.98
# RAD_id_counter= 6840		It takes 654.68
# RAD_id_counter= 6850		It takes 655.46
# RAD_id_counter= 6860		It takes 656.27
# RAD_id_counter= 6870		It takes 657.00
# RAD_id_counter= 6880		It takes 657.97
# RAD_id_counter= 6890		It takes 658.98
# RAD_id_counter= 6900		It takes 660.09
# RAD_id_counter= 6910		It takes 661.08
# RAD_id_counter= 6920		It takes 661.72
# RAD_id_counter= 6930		It takes 662.43
# RAD_id_counter= 6940		It takes 663.14
# RAD_id_counter= 6950		It takes 663.81
# RAD_id_counter= 6960		It takes 665.02
# RAD_id_counter= 6970		It takes 665.98
# RAD_id_counter= 6980		It takes 666.80
# RAD_id_counter= 6990		It takes 668.12
# RAD_id_counter= 7000		It takes 669.28
# RAD_id_counter= 7010		It takes 670.30
# RAD_id_counter= 7020		It takes 671.39
# RAD_id_counter= 7030		It takes 672.10
# RAD_id_counter= 7040		It takes 672.96
# RAD_id_counter= 7050		It takes 674.02
# RAD_id_counter= 7060		It takes 675.24
# RAD_id_counter= 7070		It takes 676.11
# RAD_id_counter= 7080		It takes 677.29
# RAD_id_counter= 7090		It takes 678.15
# RAD_id_counter= 7100		It takes 679.13
# RAD_id_counter= 7110		It takes 680.14
# RAD_id_counter= 7120		It takes 680.88
# RAD_id_counter= 7130		It takes 681.86
# RAD_id_counter= 7140		It takes 682.68
# RAD_id_counter= 7150		It takes 683.70
# RAD_id_counter= 7160		It takes 684.60
# RAD_id_counter= 7170		It takes 685.33
# RAD_id_counter= 7180		It takes 686.10
# RAD_id_counter= 7190		It takes 686.89
# RAD_id_counter= 7200		It takes 687.74
# RAD_id_counter= 7210		It takes 688.68
# RAD_id_counter= 7220		It takes 689.33
# RAD_id_counter= 7230		It takes 690.39
# RAD_id_counter= 7240		It takes 691.29
# RAD_id_counter= 7250		It takes 692.43
# RAD_id_counter= 7260		It takes 693.41
# RAD_id_counter= 7270		It takes 694.41
# RAD_id_counter= 7280		It takes 695.49
# RAD_id_counter= 7290		It takes 696.34
# RAD_id_counter= 7300		It takes 697.24
# RAD_id_counter= 7310		It takes 698.37
# RAD_id_counter= 7320		It takes 699.26
# RAD_id_counter= 7330		It takes 700.46
# RAD_id_counter= 7340		It takes 701.69
# RAD_id_counter= 7350		It takes 702.72
# RAD_id_counter= 7360		It takes 703.85
# RAD_id_counter= 7370		It takes 704.80
# RAD_id_counter= 7380		It takes 705.68
# RAD_id_counter= 7390		It takes 706.78
# RAD_id_counter= 7400		It takes 707.81
# RAD_id_counter= 7410		It takes 708.65
# RAD_id_counter= 7420		It takes 709.69
# RAD_id_counter= 7430		It takes 710.39
# RAD_id_counter= 7440		It takes 711.41
# RAD_id_counter= 7450		It takes 712.01
# RAD_id_counter= 7460		It takes 712.89
# RAD_id_counter= 7470		It takes 713.63
# RAD_id_counter= 7480		It takes 714.64
# RAD_id_counter= 7490		It takes 715.53
# RAD_id_counter= 7500		It takes 716.35
# RAD_id_counter= 7510		It takes 717.62
# RAD_id_counter= 7520		It takes 718.48
# RAD_id_counter= 7530		It takes 719.42
# RAD_id_counter= 7540		It takes 720.49
# RAD_id_counter= 7550		It takes 721.30
# RAD_id_counter= 7560		It takes 722.15
# RAD_id_counter= 7570		It takes 722.78
# RAD_id_counter= 7580		It takes 723.65
# RAD_id_counter= 7590		It takes 724.64
# RAD_id_counter= 7600		It takes 725.50
# RAD_id_counter= 7610		It takes 726.78
# RAD_id_counter= 7620		It takes 727.82
# RAD_id_counter= 7630		It takes 728.85
# RAD_id_counter= 7640		It takes 729.98
# RAD_id_counter= 7650		It takes 731.07
# RAD_id_counter= 7660		It takes 732.21
# RAD_id_counter= 7670		It takes 732.99
# RAD_id_counter= 7680		It takes 733.77
# RAD_id_counter= 7690		It takes 734.77
# RAD_id_counter= 7700		It takes 735.54
# RAD_id_counter= 7710		It takes 736.35
# RAD_id_counter= 7720		It takes 737.04
# RAD_id_counter= 7730		It takes 737.95
# RAD_id_counter= 7740		It takes 738.85
# RAD_id_counter= 7750		It takes 739.75
# RAD_id_counter= 7760		It takes 740.62
# RAD_id_counter= 7770		It takes 741.76
# RAD_id_counter= 7780		It takes 742.61
# RAD_id_counter= 7790		It takes 743.71
# RAD_id_counter= 7800		It takes 744.79
# RAD_id_counter= 7810		It takes 745.86
# RAD_id_counter= 7820		It takes 746.70
# RAD_id_counter= 7830		It takes 747.43
# RAD_id_counter= 7840		It takes 748.54
# RAD_id_counter= 7850		It takes 749.61
# RAD_id_counter= 7860		It takes 750.52
# RAD_id_counter= 7870		It takes 751.51
# RAD_id_counter= 7880		It takes 752.35
# RAD_id_counter= 7890		It takes 753.31
# RAD_id_counter= 7900		It takes 754.32
# RAD_id_counter= 7910		It takes 755.39
# RAD_id_counter= 7920		It takes 756.21
# RAD_id_counter= 7930		It takes 757.42
# RAD_id_counter= 7940		It takes 758.61
# RAD_id_counter= 7950		It takes 759.60
# RAD_id_counter= 7960		It takes 760.28
# RAD_id_counter= 7970		It takes 761.19
# RAD_id_counter= 7980		It takes 762.18
# RAD_id_counter= 7990		It takes 763.07
# It took  00:12:44
# end time: 2018-10-07 09:38:24

# %%
for RAD_id_counter, RAD_id in enumerate(RAD_id_submit_list[1775:1777]):
    result_list = predict(RAD_id, path='/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_Test_2')
    print(RAD_id)
    plt.imshow(result_list[-1], cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
    plt.show()

# %% [markdown]
# ```bash
# zip -r "SRAD2018_Neutrino_Optical_Flow_v0.2.1.1_18.10.06.01.55.zip" "SRAD2018_Neutrino_Optical_Flow_v0.2.1.1_18.10.06.01.55"
# ls | wc -l
# scp -P 50000 hadoop@222.200.177.32:~/Documents/Neutrino/SRAD2018/SRAD2018_submit/SRAD2018_Neutrino_Optical_Flow_v0.2.1.1_18.10.06.01.55.zip C:/SRAD2018/
# ```

# %% [markdown]
# # Reference
# - https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_video/py_lucas_kanade/py_lucas_kanade.html
# - https://blog.csdn.net/on2way/article/details/46801063
