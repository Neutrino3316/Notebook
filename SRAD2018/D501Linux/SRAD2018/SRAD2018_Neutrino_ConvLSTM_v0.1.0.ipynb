# %%
from IPython.display import display
from IPython.display import clear_output
import PIL
import numpy as np
import time
import os
from matplotlib.pyplot import imshow
# %matplotlib inline
import matplotlib.pyplot as plt
import gc
import sys
from matplotlib import cm
import seaborn as sns
import tensorflow as tf
import tensorlayer as tl

# %%
tf.reset_default_graph()

# %%
tf.logging.set_verbosity(tf.logging.DEBUG)

# %%
SCALAR = 80

# %%
raw_RAD_id_list = os.listdir('/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/')
print(len(raw_RAD_id_list))
# Out:
# 5000

# %%
def check_RAD_id(RAD_id):
    sum_list = []
    for k in range(61):
        sum_list.append(np.array(PIL.Image.open('/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png'
                         % (RAD_id, RAD_id,
                        k))).astype(np.int8).ravel().sum())
    sum_list = np.array(sum_list)
    if i % 100 == 0:
        print(time.strftime('%H:%M:%S', time.gmtime(time.time() - start_time)))
        print(i, sum_list[:7])
    if sum_list.mean() < 251001 * 0:
        return False
    for k in range(59):
        if abs(sum_list[k] + sum_list[k + 2] - 2 * sum_list[k + 1]) > 251001 * 2:
            return False
    return True

# %%
RAD_id_list = raw_RAD_id_list

# %%
start_time = time.time()
print(time.strftime('start time: %Y-%m-%d %H:%M:%S', time.localtime()))
RAD_id_list = []
for (i, RAD_id) in enumerate(raw_RAD_id_list[:100]):
    if check_RAD_id(RAD_id):
        RAD_id_list.append(RAD_id)
print(time.strftime('end time: %Y-%m-%d %H:%M:%S', time.localtime()))
print(time.strftime('%H:%M:%S', time.gmtime(time.time() - start_time)))
print(len(RAD_id_list))
# Out:
# start time: 2018-08-20 18:10:41
# 00:00:00
# 0 [-218731 -223051 -219804 -220007 -214895 -215379 -215980]
# end time: 2018-08-20 18:10:45
# 00:00:04
# 36

# %%
def read_by_RAD_id(RAD_id):
    x_matrix = np.empty((31, 501, 501, 1))
    for i in range(31):
        x_matrix[i] = np.array(PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png" % (RAD_id, RAD_id, i))).astype(np.int8).reshape((501, 501, 1)) / SCALAR
    y_matrix = np.empty((6, 501, 501, 1))
    for i in range(6):
        y_matrix[i] = np.array(PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png" % (RAD_id, RAD_id, i * 5 + 35))).astype(np.int8).reshape((501, 501, 1)) / SCALAR
    return ([x_matrix], [y_matrix])

# %%
all_start_time = time.time()
print(time.strftime('start time: %Y-%m-%d %H:%M:%S', time.localtime()))
# sess.close()
# with tf.device("/gpu:0"):
tf.reset_default_graph()
sess = tf.InteractiveSession()

# define placeholder
x = tf.placeholder(tf.float32, shape=[None, 31, 501, 501, 1], name='x')
y_ = tf.placeholder(tf.float32, shape=[None, 6, 501, 501, 1], name='y_')

# define the network
# network = tl.layers.InputLayer(x, name='input')
network = x
# network = tf.keras.layers.AveragePooling3D(pool_size=(3, 3, 1), data_format='channels_first')(network)
network = tf.keras.layers.ConvLSTM2D(filters=16, kernel_size=(3, 3), input_shape=network.shape, padding='same', return_sequences=True)(network)
print(network)
# network = tf.keras.layers.ConvLSTM2D(filters=64, kernel_size=(3, 3), input_shape=network.shape, padding='same', return_sequences=False)(network)
network = tf.keras.layers.Conv3D(filters=16, kernel_size=(1, 1, 1), padding='same', strides=(3, 1, 1), data_format='channels_last')(network)
network = tf.keras.layers.Conv3D(filters=16, kernel_size=(1, 1, 1), padding='same', strides=(2, 1, 1), data_format='channels_last')(network)
network = tf.keras.layers.Conv3D(filters=1, kernel_size=(1, 1, 1), padding='same', strides=(1, 1, 1), data_format='channels_last')(network)
# network = tf.keras.layers.Conv3D(filters=1, kernel_size=(1, 1, 1), padding='same', strides=(6, 1, 1), data_format='channels_last')(network)
print(network)
# network.set_shape((None, 6, 167, 167, 1))
# network = tf.keras.layers.Conv3DTranspose(filters=1, kernel_size=(1, 3, 3), strides=(1, 3, 3))(network)
print(network)

y = network
# cost = tf.losses.mean_squared_error(y, y_, weights=y_)
cost = tf.losses.mean_squared_error(y, y_)

train_op = tf.train.AdamOptimizer(learning_rate=0.001).minimize(cost)
# train_op = tf.train.GradientDescentOptimizer(learning_rate=0.01).minimize(cost)

sess.run(tf.global_variables_initializer())

n_epoch = 20
print_freq = 5

sum_cost = 0
for epoch in range(n_epoch):
    for i in range(1):
        X_train, Y_train = read_by_RAD_id(RAD_id_list[i])
        feed_dict = {x: X_train, y_: Y_train}
    #     feed_dict.update(network.all_drop)  # enable noise layers
        train_cost, _ = sess.run([cost, train_op], feed_dict=feed_dict)
        sum_cost += train_cost / (Y_train[0].sum() + 251001)
        if i % print_freq == 0:
            print('%3d'%epoch, '%3d'%i, RAD_id_list[i], time.strftime('%H:%M:%S', time.localtime()), time.strftime('%H:%M:%S', time.gmtime(time.time() - all_start_time)), '%5.5f'%(sum_cost * 10 ** 10))
        sum_cost = 0
print(time.strftime('end time: %Y-%m-%d %H:%M:%S', time.localtime()))
print(time.strftime('%H:%M:%S', time.gmtime(time.time() - all_start_time)))
# Out:
# start time: 2018-08-20 19:28:46
# Tensor("conv_lst_m2d/transpose_1:0", shape=(?, ?, 501, 501, 16), dtype=float32)
# Tensor("conv3d_2/BiasAdd:0", shape=(?, ?, 501, 501, 1), dtype=float32)
# Tensor("conv3d_2/BiasAdd:0", shape=(?, ?, 501, 501, 1), dtype=float32)
#   0   0 RAD_346482464229534 19:28:51 00:00:05 348.34188
#   1   0 RAD_346482464229534 19:28:53 00:00:06 337.37497
#   2   0 RAD_346482464229534 19:28:55 00:00:08 334.75878
#   3   0 RAD_346482464229534 19:28:56 00:00:10 336.90146
#   4   0 RAD_346482464229534 19:28:58 00:00:11 338.48064
#   5   0 RAD_346482464229534 19:28:59 00:00:13 338.03600
#   6   0 RAD_346482464229534 19:29:01 00:00:14 336.65267
#   7   0 RAD_346482464229534 19:29:02 00:00:16 335.47255
#   8   0 RAD_346482464229534 19:29:04 00:00:18 334.99854
#   9   0 RAD_346482464229534 19:29:06 00:00:19 335.10337
#  10   0 RAD_346482464229534 19:29:07 00:00:21 335.34566
#  11   0 RAD_346482464229534 19:29:09 00:00:22 335.36198
#  12   0 RAD_346482464229534 19:29:10 00:00:24 335.08462
#  13   0 RAD_346482464229534 19:29:12 00:00:25 334.69754
#  14   0 RAD_346482464229534 19:29:14 00:00:27 334.44934
#  15   0 RAD_346482464229534 19:29:15 00:00:29 334.46540
#  16   0 RAD_346482464229534 19:29:17 00:00:30 334.66453
#  17   0 RAD_346482464229534 19:29:18 00:00:32 334.84315
#  18   0 RAD_346482464229534 19:29:20 00:00:33 334.84666
#  19   0 RAD_346482464229534 19:29:22 00:00:35 334.66572
# end time: 2018-08-20 19:29:22
# 00:00:35

# %%
for i in range(1):
    X_train, Y_train = read_by_RAD_id(RAD_id_list[i])
    feed_dict = {x: X_train}
    prediction = sess.run(y, feed_dict=feed_dict)
    prediction = prediction[0] * SCALAR
    Y_validation = Y_train[0] * SCALAR
    for j in range(0, 6):
        plt.imshow(Y_validation[j].reshape((501,501)), cmap=cm.gist_ncar_r)
        plt.show()
        print('↓↓↓第%d序列，第%d次，下面的是模型的输出，上面的是真实值↑↑↑' % (i, j))
        prediction[j] = np.where(prediction[j]<3, -1, prediction[j])
        plt.imshow(prediction[j].reshape((501,501)), cmap=cm.gist_ncar_r)
        plt.show()
        print('\n------------------------------------\n')
# Out:
# ↓↓↓第0序列，第0次，下面的是模型的输出，上面的是真实值↑↑↑
# ------------------------------------
# ↓↓↓第0序列，第1次，下面的是模型的输出，上面的是真实值↑↑↑
# ------------------------------------
# ↓↓↓第0序列，第2次，下面的是模型的输出，上面的是真实值↑↑↑
# ------------------------------------
# ↓↓↓第0序列，第3次，下面的是模型的输出，上面的是真实值↑↑↑
# ------------------------------------
# ↓↓↓第0序列，第4次，下面的是模型的输出，上面的是真实值↑↑↑
# ------------------------------------
# ↓↓↓第0序列，第5次，下面的是模型的输出，上面的是真实值↑↑↑
# ------------------------------------

# %%
Y_train[0][1].shape
# Out:
# (501, 501, 1)

# %%
feed_dict = {x: X_train}
prediction = sess.run(y, feed_dict=feed_dict)
prediction = prediction[0] * SCALAR
Y_validation = Y_train[0] * SCALAR
plt.imshow(Y_validation.reshape((501,501)), cmap=cm.gist_ncar_r)
plt.show()
print('↓↓↓下面的是模型的%d输出，上面的是%d真实值↑↑↑' % (1, 1))
prediction = np.where(prediction<3, -1, prediction)
plt.imshow(prediction.reshape((501,501)), cmap=cm.gist_ncar_r)
plt.show()
print('\n------------------------------------\n')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-d1cadbc87b02> in <module>()
#       3 prediction = prediction[0] * SCALAR
#       4 Y_validation = Y_train[0] * SCALAR
# ----> 5 plt.imshow(Y_validation.reshape((501,501)), cmap=cm.gist_ncar_r)
#       6 plt.show()
#       7 print('↓↓↓下面的是模型的%d输出，上面的是%d真实值↑↑↑' % (1, 1))
#
# ValueError: cannot reshape array of size 1506006 into shape (501,501)
