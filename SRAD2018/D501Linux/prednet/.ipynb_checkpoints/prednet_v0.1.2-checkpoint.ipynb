# %%
'''
Train PredNet on KITTI sequences. (Geiger et al. 2013, http://www.cvlibs.net/datasets/kitti/)
'''

import os
import numpy as np
np.random.seed(123)
from six.moves import cPickle

import keras

from keras import backend as K
from keras.models import Model
from keras.layers import Input, Dense, Flatten
from keras.layers import LSTM
from keras.layers import TimeDistributed
from keras.callbacks import LearningRateScheduler, ModelCheckpoint
from keras.optimizers import Adam

from prednet import PredNet
# from data_utils import SequenceGenerator
from kitti_settings import *

import os
import numpy as np
import PIL
import matplotlib.pyplot as plt
from matplotlib import cm
import time

# %% [markdown]
# from data_utils import SequenceGenerator

# %%
import hickle as hkl
import numpy as np
from keras import backend as K
from keras.preprocessing.image import Iterator

# Data generator that creates sequences for input into PredNet.

# %%
SCALAR = 80
image_size = 512

raw_RAD_id_list = os.listdir('/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/')
print(len(raw_RAD_id_list))
RAD_id_list = raw_RAD_id_list
# Out:
# 5000

# %%
def check_RAD_id(RAD_id):
    sum_list = []
    for k in range(61):
        sum_list.append(np.array(PIL.Image.open('/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png'
                         % (RAD_id, RAD_id,
                        k))).astype(np.int8).ravel().sum())
    sum_list = np.array(sum_list)
    if i % 100 == 0:
        print(time.strftime('%H:%M:%S', time.gmtime(time.time() - start_time)))
        print(i, sum_list[:7])
    if sum_list.mean() < 251001 * 0:
        return False
    for k in range(59):
        if abs(sum_list[k] + sum_list[k + 2] - 2 * sum_list[k + 1]) > 251001 * 2:
            return False
    return True

# %%
start_time = time.time()
print(time.strftime('start time: %Y-%m-%d %H:%M:%S', time.localtime()))
RAD_id_list = []
for (i, RAD_id) in enumerate(raw_RAD_id_list[:100]):
    if check_RAD_id(RAD_id):
        RAD_id_list.append(RAD_id)
print(time.strftime('end time: %Y-%m-%d %H:%M:%S', time.localtime()))
print(time.strftime('%H:%M:%S', time.gmtime(time.time() - start_time)))
print(len(RAD_id_list))
# Out:
# start time: 2018-08-24 12:26:13
# 00:00:00
# 0 [-218731 -223051 -219804 -220007 -214895 -215379 -215980]
# end time: 2018-08-24 12:26:18
# 00:00:05
# 36

# %%
RAD_id = RAD_id_list[0]

# %%
class SequenceGenerator(Iterator):
    def __init__(self, data_file, source_file, nt,
                 batch_size=8, shuffle=False, seed=None,
                 output_mode='error', sequence_start_mode='all', N_seq=None,
                 data_format=K.image_data_format()):
#         self.X = hkl.load(data_file)  # X will be like (n_images, nb_cols, nb_rows, nb_channels)
#         self.sources = hkl.load(source_file) # source for each image so when creating sequences can assure that consecutive frames are from same video

#         x_matrix = np.empty((31, image_size, image_size, 1))
#         for i in range(31):
#             x_matrix[i] = np.array(PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png" % (RAD_id, RAD_id, i)).resize((image_size, image_size))).astype(np.int8).reshape((image_size, image_size, 1)) / SCALAR
#         y_matrix = np.empty((30, image_size, image_size, 1))
#         for i in range(30):
#             y_matrix[i] = np.array(PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png" % (RAD_id, RAD_id, i + 31)).resize((image_size, image_size))).astype(np.int8).reshape((image_size, image_size, 1)) / SCALAR
        self.X = x_matrix
        self.sources = y_matrix
        self.nt = nt
        self.batch_size = batch_size
        self.data_format = data_format
        assert sequence_start_mode in {'all', 'unique'}, 'sequence_start_mode must be in {all, unique}'
        self.sequence_start_mode = sequence_start_mode
        assert output_mode in {'error', 'prediction'}, 'output_mode must be in {error, prediction}'
        self.output_mode = output_mode

        if self.data_format == 'channels_first':
            self.X = np.transpose(self.X, (0, 3, 1, 2))
        self.im_shape = self.X[0].shape

        if self.sequence_start_mode == 'all':  # allow for any possible sequence, starting from any frame
            self.possible_starts = np.array([i for i in range(self.X.shape[0] - self.nt) if self.sources[i] == self.sources[i + self.nt - 1]])
        elif self.sequence_start_mode == 'unique':  #create sequences where each unique frame is in at most one sequence
            curr_location = 0
            possible_starts = []
            while curr_location < self.X.shape[0] - self.nt + 1:
                if self.sources[curr_location] == self.sources[curr_location + self.nt - 1]:
                    possible_starts.append(curr_location)
                    curr_location += self.nt
                else:
                    curr_location += 1
            self.possible_starts = possible_starts

        if shuffle:
            self.possible_starts = np.random.permutation(self.possible_starts)
        if N_seq is not None and len(self.possible_starts) > N_seq:  # select a subset of sequences if want to
            self.possible_starts = self.possible_starts[:N_seq]
        self.N_sequences = len(self.possible_starts)
        super(SequenceGenerator, self).__init__(len(self.possible_starts), batch_size, shuffle, seed)

    def next(self):
        with self.lock:
            index_array, current_index, current_batch_size = next(self.index_generator)
        batch_x = np.zeros((current_batch_size, self.nt) + self.im_shape, np.float32)
        for i, idx in enumerate(index_array):
            idx = self.possible_starts[idx]
            batch_x[i] = self.preprocess(self.X[idx:idx+self.nt])
        if self.output_mode == 'error':  # model outputs errors, so y should be zeros
            batch_y = np.zeros(current_batch_size, np.float32)
        elif self.output_mode == 'prediction':  # output actual pixels
            batch_y = batch_x
        return batch_x, batch_y

    def preprocess(self, X):
        return X.astype(np.float32) / 255

    def create_all(self):
        X_all = np.zeros((self.N_sequences, self.nt) + self.im_shape, np.float32)
        for i, idx in enumerate(self.possible_starts):
            X_all[i] = self.preprocess(self.X[idx:idx+self.nt])
        return X_all

# %%
RAD_id = RAD_id_list[0]
SCALAR = 80
size = 512

# %%
a = PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png" % (RAD_id, RAD_id, 0))

# %%
a.shape

# %%
K.image_data_format()

# %%
save_model = True  # if weights will be saved
weights_file = os.path.join(WEIGHTS_DIR, 'prednet_kitti_weights.hdf5')  # where weights will be saved
json_file = os.path.join(WEIGHTS_DIR, 'prednet_kitti_model.json')

# Data files
train_file = os.path.join(DATA_DIR, 'X_train.hkl')
train_sources = os.path.join(DATA_DIR, 'sources_train.hkl')
val_file = os.path.join(DATA_DIR, 'X_val.hkl')
val_sources = os.path.join(DATA_DIR, 'sources_val.hkl')

# Training parameters
nb_epoch = 15
batch_size = 4
samples_per_epoch = 50  # 500
N_seq_val = 10  # 100  number of sequences to use for validation

# Model parameters
n_channels, im_height, im_width = (1, image_size, image_size)  # (3, 128, 160)
input_shape = (n_channels, im_height, im_width) if K.image_data_format() == 'channels_first' else (im_height, im_width, n_channels)
stack_sizes = (n_channels, 48, 96, 192)  # (n_channels, 48, 96, 192)
R_stack_sizes = stack_sizes
A_filt_sizes = (3, 3, 3)
Ahat_filt_sizes = (3, 3, 3, 3)
R_filt_sizes = (3, 3, 3, 3)
layer_loss_weights = np.array([1., 0., 0., 0.])  # weighting for each layer in final loss; "L_0" model:  [1, 0, 0, 0], "L_all": [1, 0.1, 0.1, 0.1]
layer_loss_weights = np.expand_dims(layer_loss_weights, 1)
nt = 10  # number of timesteps used for sequences in training
time_loss_weights = 1./ (nt - 1) * np.ones((nt,1))  # equally weight all timesteps except the first
time_loss_weights[0] = 0


prednet = PredNet(stack_sizes, R_stack_sizes,
                  A_filt_sizes, Ahat_filt_sizes, R_filt_sizes, A_activation='elu', error_activation='elu',
                  output_mode='prediction', return_sequences=True)

inputs = Input(shape=(nt,) + input_shape)
outputs = prednet(inputs)
# errors = prednet(inputs)  # errors will be (batch_size, nt, nb_layers)
# errors_by_time = TimeDistributed(Dense(1, trainable=False), weights=[layer_loss_weights, np.zeros(1)], trainable=False)(errors)  # calculate weighted error by layer
# errors_by_time = Flatten()(errors_by_time)  # will be (batch_size, nt)
# final_errors = Dense(1, weights=[time_loss_weights, np.zeros(1)], trainable=False)(errors_by_time)  # weight errors by time
model = Model(inputs=inputs, outputs=outputs)
model.compile(loss='mean_absolute_error', optimizer=keras.optimizers.Adam(lr=0.001))

# %%
final_errors

# %%
train_generator = SequenceGenerator(train_file, train_sources, nt, batch_size=batch_size, shuffle=True)
val_generator = SequenceGenerator(val_file, val_sources, nt, batch_size=batch_size, N_seq=N_seq_val)

lr_schedule = lambda epoch: 0.001 if epoch < 75 else 0.0001    # start with lr of 0.001 and then drop to 0.0001 after 75 epochs
callbacks = [LearningRateScheduler(lr_schedule)]
if save_model:
    if not os.path.exists(WEIGHTS_DIR): os.mkdir(WEIGHTS_DIR)
    callbacks.append(ModelCheckpoint(filepath=weights_file, monitor='val_loss', save_best_only=True))

# %%
history = model.fit_generator(train_generator, samples_per_epoch / batch_size, nb_epoch, callbacks=callbacks,
                validation_data=val_generator, validation_steps=N_seq_val / batch_size)

if save_model:
    json_string = model.to_json()
    with open(json_file, "w") as f:
        f.write(json_string)

# %%
RAD_id = RAD_id_list[3]
x_matrix = np.empty((10, image_size, image_size, 1))
for i in range(10):
    x_matrix[i] = np.array(PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png" % (RAD_id, RAD_id, i)).resize((image_size, image_size))).astype(np.int8).reshape((image_size, image_size, 1)) / SCALAR
x_matrix = x_matrix.reshape((1, 10, image_size, image_size, 1))
y_matrix = np.empty((10, image_size, image_size, 1))
for i in range(10):
    y_matrix[i] = np.array(PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png" % (RAD_id, RAD_id, i + 10)).resize((image_size, image_size))).astype(np.int8).reshape((image_size, image_size, 1)) / SCALAR
y_matrix = y_matrix.reshape((1, 10, image_size, image_size, 1))
a = np.array(PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png" % (RAD_id, RAD_id, 0)).resize((image_size, image_size))).astype(np.int8).reshape((1, image_size, image_size, 1)) / SCALAR

# %%
model.fit([x_matrix], [y_matrix])

# %%
a = a.reshape((1, image_size, image_size, 1))

# %%
history = model.fit([x_matrix], [y_matrix], epochs=200)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 7s 7s/step - loss: 0.1098
# Epoch 2/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0917
# Epoch 3/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.1329
# Epoch 4/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0875
# Epoch 5/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0865
# Epoch 6/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0844
# Epoch 7/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0828
# Epoch 8/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0809
# Epoch 9/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0794
# Epoch 10/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0783
# Epoch 11/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0786
# Epoch 12/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0850
# Epoch 13/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0764
# Epoch 14/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0774
# Epoch 15/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0766
# Epoch 16/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0754
# Epoch 17/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0740
# Epoch 18/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0720
# Epoch 19/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0702
# Epoch 20/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0706
# Epoch 21/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0745
# Epoch 22/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0793
# Epoch 23/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0739
# Epoch 24/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0719
# Epoch 25/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0714
# Epoch 26/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0712
# Epoch 27/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0700
# Epoch 28/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0698
# Epoch 29/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0702
# Epoch 30/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0689
# Epoch 31/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0702
# Epoch 32/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0687
# Epoch 33/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0679
# Epoch 34/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0666
# Epoch 35/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0647
# Epoch 36/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0649
# Epoch 37/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0752
# Epoch 38/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0723
# Epoch 39/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0723
# Epoch 40/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0716
# Epoch 41/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0713
# Epoch 42/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0702
# Epoch 43/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0688
# Epoch 44/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0678
# Epoch 45/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0681
# Epoch 46/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0673
# Epoch 47/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0689
# Epoch 48/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0689
# Epoch 49/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0681
# Epoch 50/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0690
# Epoch 51/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0686
# Epoch 52/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0677
# Epoch 53/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0673
# Epoch 54/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0676
# Epoch 55/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0675
# Epoch 56/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0666
# Epoch 57/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0660
# Epoch 58/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0657
# Epoch 59/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0649
# Epoch 60/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0645
# Epoch 61/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0639
# Epoch 62/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0638
# Epoch 63/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0634
# Epoch 64/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0642
# Epoch 65/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0639
# Epoch 66/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0628
# Epoch 67/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0622
# Epoch 68/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0626
# Epoch 69/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0624
# Epoch 70/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0608
# Epoch 71/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0609
# Epoch 72/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0613
# Epoch 73/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0609
# Epoch 74/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0648
# Epoch 75/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0630
# Epoch 76/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0614
# Epoch 77/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0600
# Epoch 78/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0602
# Epoch 79/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0601
# Epoch 80/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0595
# Epoch 81/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0593
# Epoch 82/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0591
# Epoch 83/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0586
# Epoch 84/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0579
# Epoch 85/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0576
# Epoch 86/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0576
# Epoch 87/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0586
# Epoch 88/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0613
# Epoch 89/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0595
# Epoch 90/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0576
# Epoch 91/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0591
# Epoch 92/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0580
# Epoch 93/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0576
# Epoch 94/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0572
# Epoch 95/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0567
# Epoch 96/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0565
# Epoch 97/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0561
# Epoch 98/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0560
# Epoch 99/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0556
# Epoch 100/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0550
# Epoch 101/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0551
# Epoch 102/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0569
# Epoch 103/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0554
# Epoch 104/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0547
# Epoch 105/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0547
# Epoch 106/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0547
# Epoch 107/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0541
# Epoch 108/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0535
# Epoch 109/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0537
# Epoch 110/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0532
# Epoch 111/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0528
# Epoch 112/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0525
# Epoch 113/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0522
# Epoch 114/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0536
# Epoch 115/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0526
# Epoch 116/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0523
# Epoch 117/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0542
# Epoch 118/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0539
# Epoch 119/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0532
# Epoch 120/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0532
# Epoch 121/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0534
# Epoch 122/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0516
# Epoch 123/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0523
# Epoch 124/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0519
# Epoch 125/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0514
# Epoch 126/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0516
# Epoch 127/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0512
# Epoch 128/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0510
# Epoch 129/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0506
# Epoch 130/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0503
# Epoch 131/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0509
# Epoch 132/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0512
# Epoch 133/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0509
# Epoch 134/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0504
# Epoch 135/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0502
# Epoch 136/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0499
# Epoch 137/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0493
# Epoch 138/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0491
# Epoch 139/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0488
# Epoch 140/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0507
# Epoch 141/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0549
# Epoch 142/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0527
# Epoch 143/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0513
# Epoch 144/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0506
# Epoch 145/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0507
# Epoch 146/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0504
# Epoch 147/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0501
# Epoch 148/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0499
# Epoch 149/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0491
# Epoch 150/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0491
# Epoch 151/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0487
# Epoch 152/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0483
# Epoch 153/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0481
# Epoch 154/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0480
# Epoch 155/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0477
# Epoch 156/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0474
# Epoch 157/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0470
# Epoch 158/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0468
# Epoch 159/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0466
# Epoch 160/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0469
# Epoch 161/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0477
# Epoch 162/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0483
# Epoch 163/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0468
# Epoch 164/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0473
# Epoch 165/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0471
# Epoch 166/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0470
# Epoch 167/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0473
# Epoch 168/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0465
# Epoch 169/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0464
# Epoch 170/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0461
# Epoch 171/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0462
# Epoch 172/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0462
# Epoch 173/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0460
# Epoch 174/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0455
# Epoch 175/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0454
# Epoch 176/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0456
# Epoch 177/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0457
# Epoch 178/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0457
# Epoch 179/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0448
# Epoch 180/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0456
# Epoch 181/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0452
# Epoch 182/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0443
# Epoch 183/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0452
# Epoch 184/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0447
# Epoch 185/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0446
# Epoch 186/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0442
# Epoch 187/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0440
# Epoch 188/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0438
# Epoch 189/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0435
# Epoch 190/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0434
# Epoch 191/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0432
# Epoch 192/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0429
# Epoch 193/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0432
# Epoch 194/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0432
# Epoch 195/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0429
# Epoch 196/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0424
# Epoch 197/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0424
# Epoch 198/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0422
# Epoch 199/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0421
# Epoch 200/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0418

# %%
history

# %%
b = model.predict([x_matrix])

# %%
y_matrix.shape
# Out:
# (1, 10, 512, 512, 1)

# %%
for i in range(10):
    plt.imshow(y_matrix[0][i].reshape((image_size, image_size)) * SCALAR, cmap=cm.gist_ncar_r)
    plt.show()
    print('↓↓↓下面的是模型的%d输出，上面的是%d真实值↑↑↑' % (i, i))
    plt.imshow(b[0][i].reshape((image_size, image_size)) * SCALAR, cmap=cm.gist_ncar_r)
    plt.show()
# Out:
# ↓↓↓下面的是模型的0输出，上面的是0真实值↑↑↑
# ↓↓↓下面的是模型的1输出，上面的是1真实值↑↑↑
# ↓↓↓下面的是模型的2输出，上面的是2真实值↑↑↑
# ↓↓↓下面的是模型的3输出，上面的是3真实值↑↑↑
# ↓↓↓下面的是模型的4输出，上面的是4真实值↑↑↑
# ↓↓↓下面的是模型的5输出，上面的是5真实值↑↑↑
# ↓↓↓下面的是模型的6输出，上面的是6真实值↑↑↑
# ↓↓↓下面的是模型的7输出，上面的是7真实值↑↑↑
# ↓↓↓下面的是模型的8输出，上面的是8真实值↑↑↑
# ↓↓↓下面的是模型的9输出，上面的是9真实值↑↑↑

# %%
plt.imshow(a.reshape((image_size, image_size)) * SCALAR, cmap=cm.gist_ncar_r)
plt.show()
print('↓↓↓下面的是模型的%d输出，上面的是%d真实值↑↑↑' % (1, 1))
plt.imshow(b.reshape((image_size, image_size)) * SCALAR, cmap=cm.gist_ncar_r)
plt.show()
# Out:
# ↓↓↓下面的是模型的1输出，上面的是1真实值↑↑↑

# %%
input_shape = list(model.layers[0].batch_input_shape[1:])
input_shape[0] = nt
inputs = Input(shape=tuple(input_shape))

# %%
print(x_matrix.shape)
print(y_matrix.shape)
print(a.shape)
# Out:
# (1, 10, 512, 512, 1)
# (1, 10, 512, 512, 1)
# (512, 512, 1)

# %%
print(model.get_input_shape_at(0))
print(model.get_output_shape_at(0))
# Out:
# (None, 10, 512, 512, 1)
# (None, 512, 512, 1)
