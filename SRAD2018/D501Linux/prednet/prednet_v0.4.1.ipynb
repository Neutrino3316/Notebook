# %%
import os
import numpy as np
np.random.seed(123)
from six.moves import cPickle

import keras
import tensorflow as tf

from keras import backend as K
# from keras.models import Model
from keras.layers import Input, Dense, Flatten
from keras.layers import LSTM
from keras.layers import TimeDistributed
from keras.callbacks import LearningRateScheduler, ModelCheckpoint
from keras.optimizers import Adam

# from prednet import PredNet
# # from data_utils import SequenceGenerator
# from kitti_settings import *

import os
import numpy as np
import PIL
import matplotlib.pyplot as plt
from matplotlib import cm
import time
import multiprocessing
import random
import sklearn
import seaborn as sns
import cv2
import skimage
from skimage import restoration
import copy

# %%
from keras import backend as K
from keras import activations
from keras.layers import Recurrent
from keras.layers import Conv2D, UpSampling2D, MaxPooling2D
from keras.engine import InputSpec
# from keras_utils import legacy_prednet_support

class PredNet(Recurrent):
    '''PredNet architecture - Lotter 2016.
        Stacked convolutional LSTM inspired by predictive coding principles.

    # Arguments
        stack_sizes: number of channels in targets (A) and predictions (Ahat) in each layer of the architecture.
            Length is the number of layers in the architecture.
            First element is the number of channels in the input.
            Ex. (3, 16, 32) would correspond to a 3 layer architecture that takes in RGB images and has 16 and 32
                channels in the second and third layers, respectively.
        R_stack_sizes: number of channels in the representation (R) modules.
            Length must equal length of stack_sizes, but the number of channels per layer can be different.
        A_filt_sizes: filter sizes for the target (A) modules.
            Has length of 1 - len(stack_sizes).
            Ex. (3, 3) would mean that targets for layers 2 and 3 are computed by a 3x3 convolution of the errors (E)
                from the layer below (followed by max-pooling)
        Ahat_filt_sizes: filter sizes for the prediction (Ahat) modules.
            Has length equal to length of stack_sizes.
            Ex. (3, 3, 3) would mean that the predictions for each layer are computed by a 3x3 convolution of the
                representation (R) modules at each layer.
        R_filt_sizes: filter sizes for the representation (R) modules.
            Has length equal to length of stack_sizes.
            Corresponds to the filter sizes for all convolutions in the LSTM.
        pixel_max: the maximum pixel value.
            Used to clip the pixel-layer prediction.
        error_activation: activation function for the error (E) units.
        A_activation: activation function for the target (A) and prediction (A_hat) units.
        LSTM_activation: activation function for the cell and hidden states of the LSTM.
        LSTM_inner_activation: activation function for the gates in the LSTM.
        output_mode: either 'error', 'prediction', 'all' or layer specification (ex. R2, see below).
            Controls what is outputted by the PredNet.
            If 'error', the mean response of the error (E) units of each layer will be outputted.
                That is, the output shape will be (batch_size, nb_layers).
            If 'prediction', the frame prediction will be outputted.
            If 'all', the output will be the frame prediction concatenated with the mean layer errors.
                The frame prediction is flattened before concatenation.
                Nomenclature of 'all' is kept for backwards compatibility, but should not be confused with returning all of the layers of the model
            For returning the features of a particular layer, output_mode should be of the form unit_type + layer_number.
                For instance, to return the features of the LSTM "representational" units in the lowest layer, output_mode should be specificied as 'R0'.
                The possible unit types are 'R', 'Ahat', 'A', and 'E' corresponding to the 'representation', 'prediction', 'target', and 'error' units respectively.
        extrap_start_time: time step for which model will start extrapolating.
            Starting at this time step, the prediction from the previous time step will be treated as the "actual"
        data_format: 'channels_first' or 'channels_last'.
            It defaults to the `image_data_format` value found in your
            Keras config file at `~/.keras/keras.json`.

    # References
        - [Deep predictive coding networks for video prediction and unsupervised learning](https://arxiv.org/abs/1605.08104)
        - [Long short-term memory](http://deeplearning.cs.cmu.edu/pdfs/Hochreiter97_lstm.pdf)
        - [Convolutional LSTM network: a machine learning approach for precipitation nowcasting](http://arxiv.org/abs/1506.04214)
        - [Predictive coding in the visual cortex: a functional interpretation of some extra-classical receptive-field effects](http://www.nature.com/neuro/journal/v2/n1/pdf/nn0199_79.pdf)
    '''
#     @legacy_prednet_support
    def __init__(self, stack_sizes, R_stack_sizes,
                 A_filt_sizes, Ahat_filt_sizes, R_filt_sizes,
                 pixel_max=1., error_activation='relu', A_activation='relu',
                 LSTM_activation='tanh', LSTM_inner_activation='hard_sigmoid',
                 conv_dropout=0.8,
                 output_mode='error', extrap_start_time=None,
                 data_format=K.image_data_format(), **kwargs):
        self.stack_sizes = stack_sizes
        self.nb_layers = len(stack_sizes)
        assert len(R_stack_sizes) == self.nb_layers, 'len(R_stack_sizes) must equal len(stack_sizes)'
        self.R_stack_sizes = R_stack_sizes
        assert len(A_filt_sizes) == (self.nb_layers - 1), 'len(A_filt_sizes) must equal len(stack_sizes) - 1'
        self.A_filt_sizes = A_filt_sizes
        assert len(Ahat_filt_sizes) == self.nb_layers, 'len(Ahat_filt_sizes) must equal len(stack_sizes)'
        self.Ahat_filt_sizes = Ahat_filt_sizes
        assert len(R_filt_sizes) == (self.nb_layers), 'len(R_filt_sizes) must equal len(stack_sizes)'
        self.R_filt_sizes = R_filt_sizes

        self.pixel_max = pixel_max
        self.error_activation = activations.get(error_activation)
        self.A_activation = activations.get(A_activation)
        self.LSTM_activation = activations.get(LSTM_activation)
        self.LSTM_inner_activation = activations.get(LSTM_inner_activation)
        self.conv_dropout = conv_dropout

        default_output_modes = ['prediction', 'error', 'all']
        layer_output_modes = [layer + str(n) for n in range(self.nb_layers) for layer in ['R', 'E', 'A', 'Ahat']]
        assert output_mode in default_output_modes + layer_output_modes, 'Invalid output_mode: ' + str(output_mode)
        self.output_mode = output_mode
        if self.output_mode in layer_output_modes:
            self.output_layer_type = self.output_mode[:-1]
            self.output_layer_num = int(self.output_mode[-1])
        else:
            self.output_layer_type = None
            self.output_layer_num = None
        self.extrap_start_time = extrap_start_time

        assert data_format in {'channels_last', 'channels_first'}, 'data_format must be in {channels_last, channels_first}'
        self.data_format = data_format
        self.channel_axis = -3 if data_format == 'channels_first' else -1
        self.row_axis = -2 if data_format == 'channels_first' else -3
        self.column_axis = -1 if data_format == 'channels_first' else -2
        super(PredNet, self).__init__(**kwargs)
        self.input_spec = [InputSpec(ndim=5)]

    def compute_output_shape(self, input_shape):
        if self.output_mode == 'prediction':
            out_shape = input_shape[2:]
        elif self.output_mode == 'error':
            out_shape = (self.nb_layers,)
        elif self.output_mode == 'all':
            out_shape = (np.prod(input_shape[2:]) + self.nb_layers,)
        else:
            stack_str = 'R_stack_sizes' if self.output_layer_type == 'R' else 'stack_sizes'
            stack_mult = 2 if self.output_layer_type == 'E' else 1
            out_stack_size = stack_mult * getattr(self, stack_str)[self.output_layer_num]
            out_nb_row = input_shape[self.row_axis] / 2**self.output_layer_num
            out_nb_col = input_shape[self.column_axis] / 2**self.output_layer_num
            if self.data_format == 'channels_first':
                out_shape = (out_stack_size, out_nb_row, out_nb_col)
            else:
                out_shape = (out_nb_row, out_nb_col, out_stack_size)

        if self.return_sequences:
            return (input_shape[0], input_shape[1]) + out_shape
        else:
            return (input_shape[0],) + out_shape

    def get_initial_state(self, x):
        input_shape = self.input_spec[0].shape
        init_nb_row = input_shape[self.row_axis]
        init_nb_col = input_shape[self.column_axis]

        base_initial_state = K.zeros_like(x)  # (samples, timesteps) + image_shape
        non_channel_axis = -1 if self.data_format == 'channels_first' else -2
        for _ in range(2):
            base_initial_state = K.sum(base_initial_state, axis=non_channel_axis)
        base_initial_state = K.sum(base_initial_state, axis=1)  # (samples, nb_channels)

        initial_states = []
        states_to_pass = ['r', 'c', 'e']
        nlayers_to_pass = {u: self.nb_layers for u in states_to_pass}
        if self.extrap_start_time is not None:
            states_to_pass.append('ahat')  # pass prediction in states so can use as actual for t+1 when extrapolating
            nlayers_to_pass['ahat'] = 1
        for u in states_to_pass:
            for l in range(nlayers_to_pass[u]):
                ds_factor = 2 ** l
                nb_row = init_nb_row // ds_factor
                nb_col = init_nb_col // ds_factor
                if u in ['r', 'c']:
                    stack_size = self.R_stack_sizes[l]
                elif u == 'e':
                    stack_size = 2 * self.stack_sizes[l]
                elif u == 'ahat':
                    stack_size = self.stack_sizes[l]
                output_size = stack_size * nb_row * nb_col  # flattened size

                reducer = K.zeros((input_shape[self.channel_axis], output_size)) # (nb_channels, output_size)
                initial_state = K.dot(base_initial_state, reducer) # (samples, output_size)
                if self.data_format == 'channels_first':
                    output_shp = (-1, stack_size, nb_row, nb_col)
                else:
                    output_shp = (-1, nb_row, nb_col, stack_size)
                initial_state = K.reshape(initial_state, output_shp)
                initial_states += [initial_state]

        if K._BACKEND == 'theano':
            from theano import tensor as T
            # There is a known issue in the Theano scan op when dealing with inputs whose shape is 1 along a dimension.
            # In our case, this is a problem when training on grayscale images, and the below line fixes it.
            initial_states = [T.unbroadcast(init_state, 0, 1) for init_state in initial_states]

        if self.extrap_start_time is not None:
            initial_states += [K.variable(0, int if K.backend() != 'tensorflow' else 'int32')]  # the last state will correspond to the current timestep
        return initial_states

    def build(self, input_shape):
        self.input_spec = [InputSpec(shape=input_shape)]
        self.conv_layers = {c: [] for c in ['i', 'f', 'c', 'o', 'a', 'ahat']}

        for l in range(self.nb_layers):
            for c in ['i', 'f', 'c', 'o']:
                act = self.LSTM_activation if c == 'c' else self.LSTM_inner_activation
                self.conv_layers[c].append(Conv2D(self.R_stack_sizes[l], self.R_filt_sizes[l], padding='same', activation=act, data_format=self.data_format))
#                 self.conv_layers[c].append(keras.layers.Dropout(self.conv_dropout))

            act = 'relu' if l == 0 else self.A_activation
            self.conv_layers['ahat'].append(Conv2D(self.stack_sizes[l], self.Ahat_filt_sizes[l], padding='same', activation=act, data_format=self.data_format))

            if l < self.nb_layers - 1:
                self.conv_layers['a'].append(Conv2D(self.stack_sizes[l+1], self.A_filt_sizes[l], padding='same', activation=self.A_activation, data_format=self.data_format))

        self.upsample = UpSampling2D(data_format=self.data_format)
        self.pool = MaxPooling2D(data_format=self.data_format)

        self.trainable_weights = []
        nb_row, nb_col = (input_shape[-2], input_shape[-1]) if self.data_format == 'channels_first' else (input_shape[-3], input_shape[-2])
        for c in sorted(self.conv_layers.keys()):
            for l in range(len(self.conv_layers[c])):
                ds_factor = 2 ** l
                if c == 'ahat':
                    nb_channels = self.R_stack_sizes[l]
                elif c == 'a':
                    nb_channels = 2 * self.R_stack_sizes[l]
                else:
                    nb_channels = self.stack_sizes[l] * 2 + self.R_stack_sizes[l]
                    if l < self.nb_layers - 1:
                        nb_channels += self.R_stack_sizes[l+1]
                in_shape = (input_shape[0], nb_channels, nb_row // ds_factor, nb_col // ds_factor)
                if self.data_format == 'channels_last': in_shape = (in_shape[0], in_shape[2], in_shape[3], in_shape[1])
                with K.name_scope('layer_' + c + '_' + str(l)):
                    self.conv_layers[c][l].build(in_shape)
                self.trainable_weights += self.conv_layers[c][l].trainable_weights

        self.states = [None] * self.nb_layers*3

        if self.extrap_start_time is not None:
            self.t_extrap = K.variable(self.extrap_start_time, int if K.backend() != 'tensorflow' else 'int32')
            self.states += [None] * 2  # [previous frame prediction, timestep]

    def step(self, a, states):
        r_tm1 = states[:self.nb_layers]
        c_tm1 = states[self.nb_layers:2*self.nb_layers]
        e_tm1 = states[2*self.nb_layers:3*self.nb_layers]

        if self.extrap_start_time is not None:
            t = states[-1]
            a = K.switch(t >= self.t_extrap, states[-2], a)  # if past self.extrap_start_time, the previous prediction will be treated as the actual

        c = []
        r = []
        e = []

        # Update R units starting from the top
        for l in reversed(range(self.nb_layers)):
            inputs = [r_tm1[l], e_tm1[l]]
            if l < self.nb_layers - 1:
                inputs.append(r_up)

            inputs = K.concatenate(inputs, axis=self.channel_axis)
            i = self.conv_layers['i'][l].call(inputs)
            f = self.conv_layers['f'][l].call(inputs)
            o = self.conv_layers['o'][l].call(inputs)
            _c = f * c_tm1[l] + i * self.conv_layers['c'][l].call(inputs)
            _r = o * self.LSTM_activation(_c)
            c.insert(0, _c)
            r.insert(0, _r)

            if l > 0:
                r_up = self.upsample.call(_r)

        # Update feedforward path starting from the bottom
        for l in range(self.nb_layers):
            ahat = self.conv_layers['ahat'][l].call(r[l])
            if l == 0:
                ahat = K.minimum(ahat, self.pixel_max)
                frame_prediction = ahat

            # compute errors
            e_up = self.error_activation(ahat - a)
            e_down = self.error_activation(a - ahat)

            e.append(K.concatenate((e_up, e_down), axis=self.channel_axis))

            if self.output_layer_num == l:
                if self.output_layer_type == 'A':
                    output = a
                elif self.output_layer_type == 'Ahat':
                    output = ahat
                elif self.output_layer_type == 'R':
                    output = r[l]
                elif self.output_layer_type == 'E':
                    output = e[l]

            if l < self.nb_layers - 1:
                a = self.conv_layers['a'][l].call(e[l])
                a = self.pool.call(a)  # target for next layer

        if self.output_layer_type is None:
            if self.output_mode == 'prediction':
                output = frame_prediction
            else:
                for l in range(self.nb_layers):
                    layer_error = K.mean(K.batch_flatten(e[l]), axis=-1, keepdims=True)
                    all_error = layer_error if l == 0 else K.concatenate((all_error, layer_error), axis=-1)
                if self.output_mode == 'error':
                    output = all_error
                else:
                    output = K.concatenate((K.batch_flatten(frame_prediction), all_error), axis=-1)

        states = r + c + e
        if self.extrap_start_time is not None:
            states += [frame_prediction, t + 1]
        return output, states

    def get_config(self):
        config = {'stack_sizes': self.stack_sizes,
                  'R_stack_sizes': self.R_stack_sizes,
                  'A_filt_sizes': self.A_filt_sizes,
                  'Ahat_filt_sizes': self.Ahat_filt_sizes,
                  'R_filt_sizes': self.R_filt_sizes,
                  'pixel_max': self.pixel_max,
                  'error_activation': self.error_activation.__name__,
                  'A_activation': self.A_activation.__name__,
                  'LSTM_activation': self.LSTM_activation.__name__,
                  'LSTM_inner_activation': self.LSTM_inner_activation.__name__,
                  'data_format': self.data_format,
                  'extrap_start_time': self.extrap_start_time,
                  'output_mode': self.output_mode}
        base_config = super(PredNet, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))
print(time.strftime('build time: %Y-%m-%d %H:%M:%S', time.localtime()))
# Out:
# build time: 2018-09-07 01:45:00

# %%
raw_RAD_id_list = os.listdir('/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/')
print(len(raw_RAD_id_list))
RAD_id_list = raw_RAD_id_list
# Out:
# 15000

# %%
def check_RAD_id(RAD_id):
    mean_list = []
    for k in range(61):
        mean_list.append(np.array(PIL.Image.open('/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png'
                         % (RAD_id, RAD_id,
                        k))).astype(np.int8).ravel().mean())
    mean_list = np.array(mean_list)
    if mean_list.mean() < -0.5:
        return None
    for k in range(59):
        if abs(mean_list[k] + mean_list[k + 2] - 2 * mean_list[k + 1]) > 2:
            return None
    return RAD_id

# %%
pool = multiprocessing.Pool()
start_time = time.time()
print(time.strftime('start time: %Y-%m-%d %H:%M:%S', time.localtime()))
# map(check_RAD_id, raw_RAD_id_list[:100])
# print(time.strftime('start time: %Y-%m-%d %H:%M:%S', time.localtime()))
RAD_id_list = list(pool.map(check_RAD_id, raw_RAD_id_list))
RAD_id_list = [x for x in RAD_id_list if x is not None]
print(time.strftime('end time: %Y-%m-%d %H:%M:%S', time.localtime()))
print(time.strftime('%H:%M:%S', time.gmtime(time.time() - start_time)))
print(len(RAD_id_list))
# Out:
# start time: 2018-09-07 01:45:00
# end time: 2018-09-07 01:45:45
# 00:00:45
# 6562
# Process ForkPoolWorker-14:
# Process ForkPoolWorker-25:
# Traceback (most recent call last):
# Process ForkPoolWorker-11:
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-31:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-22:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-10:
# Traceback (most recent call last):
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-5:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
# Process ForkPoolWorker-13:
# Traceback (most recent call last):
# Process ForkPoolWorker-32:
# Process ForkPoolWorker-20:
# Process ForkPoolWorker-30:
# Process ForkPoolWorker-26:
# Process ForkPoolWorker-27:
# Process ForkPoolWorker-29:
# Traceback (most recent call last):
# Process ForkPoolWorker-15:
# Process ForkPoolWorker-16:
# Process ForkPoolWorker-23:
# Traceback (most recent call last):
# Process ForkPoolWorker-19:
# Process ForkPoolWorker-12:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Process ForkPoolWorker-28:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-17:
# Process ForkPoolWorker-9:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-4:
# Traceback (most recent call last):
# Process ForkPoolWorker-24:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process ForkPoolWorker-18:
# Process ForkPoolWorker-21:
# Process ForkPoolWorker-1:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 343, in get
#     res = self._reader.recv_bytes()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt

# %%
step_size = 5

class trainGenerator(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, nt, image_size, image_scalar, batch_size=32, shuffle=True):
        'Initialization'
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.shuffle = shuffle
        self.nt = nt
        self.image_size = image_size
        self.image_scalar = image_scalar
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        # Find list of IDs
        list_IDs_temp = [self.list_IDs[k] for k in indexes]
        # Generate data
        X, y = self.__data_generation(list_IDs_temp)
        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, list_IDs_temp):
#         'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
#         X = np.empty((self.batch_size, self.nt, self.image_size, self.image_size, 3))
# #         y = np.empty((self.batch_size, self.image_size, self.image_size, 1))
#         for i, RAD_id in enumerate(list_IDs_temp):
#             offset = random.randint(0, 61 - self.nt * step_size)
#             offset = random.randint(2, 59 - self.nt * step_size)
#             for j in range(self.nt):
# #                 X[i][j] = (np.array(PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png" % (RAD_id, RAD_id, j * step_size + offset)).resize((self.image_size, self.image_size))).astype(np.int8).reshape((self.image_size, self.image_size, 1)) / self.image_scalar + 
# #                     np.array(PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png" % (RAD_id, RAD_id, j * step_size + offset + 1)).resize((self.image_size, self.image_size))).astype(np.int8).reshape((self.image_size, self.image_size, 1)) / self.image_scalar + 
# #                     np.array(PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png" % (RAD_id, RAD_id, j * step_size + offset - 1)).resize((self.image_size, self.image_size))).astype(np.int8).reshape((self.image_size, self.image_size, 1)) / self.image_scalar) / 3
#                 temp_matrix = np.empty((3, self.image_size, self.image_size))
#                 temp_matrix[0] = np.array(PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png" % (RAD_id, RAD_id, j * step_size + offset - 1)).resize((self.image_size, self.image_size))).astype(np.int8) / self.image_scalar + \
#                                  np.array(PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png" % (RAD_id, RAD_id, j * step_size + offset - 2)).resize((self.image_size, self.image_size))).astype(np.int8) / self.image_scalar
#                 temp_matrix[1] = np.array(PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png" % (RAD_id, RAD_id, j * step_size + offset)).resize((self.image_size, self.image_size))).astype(np.int8) / self.image_scalar * 2
#                 temp_matrix[2] = np.array(PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png" % (RAD_id, RAD_id, j * step_size + offset + 1)).resize((self.image_size, self.image_size))).astype(np.int8) / self.image_scalar + \
#                                  np.array(PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png" % (RAD_id, RAD_id, j * step_size + offset + 2)).resize((self.image_size, self.image_size))).astype(np.int8) / self.image_scalar
# #                 temp_matrix[2] = temp_matrix[2] - temp_matrix[1]
# #                 temp_matrix[0] = temp_matrix[1] - temp_matrix[0]
#                 temp_matrix[0] = cv2.GaussianBlur(temp_matrix[1], (5, 5), 0)
#                 temp_matrix[1] = cv2.GaussianBlur(temp_matrix[1], (9, 9), 0)
#                 temp_matrix[2] = cv2.GaussianBlur(temp_matrix[1], (13, 13), 0)
#                 temp_matrix = np.rollaxis(temp_matrix, 0, 3)
#                 X[i][j] = temp_matrix
# #             y[i] = np.array(PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png" % (RAD_id, RAD_id, (self.nt) * 1)).resize((self.image_size, self.image_size))).astype(np.int8).reshape((self.image_size, self.image_size, 1)) / self.image_scalar
        X, y = data_generation(list_IDs_temp, batch_size=self.batch_size, image_size=self.image_size, nt=self.nt, step_size=step_size, image_scalar=self.image_scalar)
        y = np.zeros(self.batch_size, np.float32)
        return X, y
print(time.strftime('build time: %Y-%m-%d %H:%M:%S', time.localtime()))
# Out:
# build time: 2018-09-07 01:54:49

# %%
n_channels = 3
def data_generation(list_IDs_temp, batch_size, image_size, nt, step_size, image_scalar, offset=None, path='/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train'):
    '''
    nt * step_size + offset = 60
    '''
    X = np.empty((batch_size, nt, image_size, image_size, n_channels))
    y = np.empty((batch_size, image_size, image_size, n_channels))
    for i, RAD_id in enumerate(list_IDs_temp):
#         offset = random.randint(0, 61 - nt * step_size)
        if offset == None:
            offset = random.randint(2, 59 - nt * step_size)
        for j in range(nt):
            temp_matrix = np.empty((n_channels, image_size, image_size))
#             temp_matrix[0] = np.array(PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png" % (RAD_id, RAD_id, j * step_size + offset - 1)).resize((image_size, image_size))).astype(np.int8) / image_scalar + \
#                              np.array(PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png" % (RAD_id, RAD_id, j * step_size + offset - 2)).resize((image_size, image_size))).astype(np.int8) / image_scalar
            temp_matrix[0] = np.array(PIL.Image.open("%s/%s/%s_%03d.png" % (path, RAD_id, RAD_id, j * step_size + offset)).resize((image_size, image_size))).astype(np.int8) / image_scalar
#             temp_matrix[2] = np.array(PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png" % (RAD_id, RAD_id, j * step_size + offset + 1)).resize((image_size, image_size))).astype(np.int8) / image_scalar + \
#                              np.array(PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png" % (RAD_id, RAD_id, j * step_size + offset + 2)).resize((image_size, image_size))).astype(np.int8) / image_scalar
            temp_matrix[1] = cv2.GaussianBlur(temp_matrix[0], (5, 5), 0)
            temp_matrix[0] = cv2.GaussianBlur(temp_matrix[0], (9, 9), 0)
            temp_matrix[2] = cv2.GaussianBlur(temp_matrix[0], (13, 13), 0)
            temp_matrix = np.rollaxis(temp_matrix, 0, 3)
            X[i][j] = temp_matrix
        temp_matrix = np.empty((n_channels, image_size, image_size))
        temp_matrix[0] = np.array(PIL.Image.open("%s/%s/%s_%03d.png" % (path, RAD_id, RAD_id, nt * step_size + offset)).resize((image_size, image_size))).astype(np.int8) / image_scalar
        temp_matrix[1] = cv2.GaussianBlur(temp_matrix[0], (5, 5), 0)
        temp_matrix[0] = cv2.GaussianBlur(temp_matrix[0], (9, 9), 0)
        temp_matrix[2] = cv2.GaussianBlur(temp_matrix[0], (13, 13), 0)
        temp_matrix = np.rollaxis(temp_matrix, 0, 3)
        y[i] = temp_matrix
    return X, y

# %%
# Model parameters
image_size = 256
nt = 6 # number of timesteps used for sequences in training
image_scalar = 80
vmin = -1
vmax = 0.6 * image_scalar
n_channels, im_height, im_width = (n_channels, image_size, image_size)  # (3, 128, 160)
input_shape = (n_channels, im_height, im_width) if K.image_data_format() == 'channels_first' else (im_height, im_width, n_channels)
stack_sizes = (n_channels, 48, 96, 192)
R_stack_sizes = stack_sizes
A_filt_sizes = (3, 3, 3)
Ahat_filt_sizes = (3, 3, 3, 3)
R_filt_sizes = (3, 3, 3, 3)
layer_loss_weights = np.array([1., 0., 0., 0.])  # weighting for each layer in final loss; "L_0" model:  [1, 0, 0, 0], "L_all": [1, 0.1, 0.1, 0.1]
layer_loss_weights = np.expand_dims(layer_loss_weights, 1)
time_loss_weights = 1./ (nt - 1) * np.ones((nt,1))  # equally weight all timesteps except the first
time_loss_weights[0] = 0


prednet = PredNet(stack_sizes, R_stack_sizes,
                  A_filt_sizes, Ahat_filt_sizes, R_filt_sizes,
                  A_activation=tf.nn.elu, error_activation=tf.nn.elu,
                  LSTM_inner_activation='sigmoid',
                  output_mode='error', return_sequences=True, extrap_start_time=2)

inputs = Input(shape=(nt,) + input_shape)
errors = prednet(inputs)  # errors will be (batch_size, nt, nb_layers)
errors_by_time = TimeDistributed(Dense(1, trainable=False), weights=[layer_loss_weights, np.zeros(1)], trainable=False)(errors)  # calculate weighted error by layer
errors_by_time = Flatten()(errors_by_time)  # will be (batch_size, nt)
final_errors = Dense(1, weights=[time_loss_weights, np.zeros(1)], trainable=False)(errors_by_time)  # weight errors by time
outputs = final_errors
# outputs = np.empty(shape=(nt,) + input_shape)
# for i in range(nt):
#     temp_outputs = prednet(inputs)
#     outputs[i] = temp_outputs
#     for j in range(nt - 1):
#         inputs[j] = inputs[j + 1]
#     inputs[-1] = temp_outputs

def my_loss(y_true, y_pred):
#     w = tf.add(y_true, tf.constant(0.5))
#     w = tf.add(y_pred, w)
#     loss = tf.losses.mean_squared_error(y_true, y_pred, weights=w)
#     loss = tf.losses.mean_squared_error(y_true, y_pred)
    loss = tf.losses.absolute_difference(y_true, y_pred)
#     loss = tf.multiply(loss, tf.constant(1000000000.0))
    return loss

model = keras.models.Model(inputs=inputs, outputs=outputs)
model.compile(loss=my_loss, optimizer=keras.optimizers.Adam())
print(time.strftime('build time: %Y-%m-%d %H:%M:%S', time.localtime()))
# Out:
# build time: 2018-09-07 01:54:52

# %% [markdown]
# ```python
#
# # Model parameters
# image_size = 256
# nt = 6 # number of timesteps used for sequences in training
# image_scalar = 80
# vmin = -1
# vmax = 0.6 * image_scalar
# n_channels, im_height, im_width = (n_channels, image_size, image_size)  # (3, 128, 160)
# input_shape = (n_channels, im_height, im_width) if K.image_data_format() == 'channels_first' else (im_height, im_width, n_channels)
# stack_sizes = (n_channels, 48, 96, 192)
# R_stack_sizes = stack_sizes
# A_filt_sizes = (3, 3, 3)
# Ahat_filt_sizes = (3, 3, 3, 3)
# R_filt_sizes = (3, 3, 3, 3)
# layer_loss_weights = np.array([1., 0., 0., 0.])  # weighting for each layer in final loss; "L_0" model:  [1, 0, 0, 0], "L_all": [1, 0.1, 0.1, 0.1]
# layer_loss_weights = np.expand_dims(layer_loss_weights, 1)
# time_loss_weights = 1./ (nt - 1) * np.ones((nt,1))  # equally weight all timesteps except the first
# time_loss_weights[0] = 0
#
#
# prednet = PredNet(stack_sizes, R_stack_sizes,
#                   A_filt_sizes, Ahat_filt_sizes, R_filt_sizes,
#                   A_activation=tf.nn.elu, error_activation=tf.nn.elu,
#                   LSTM_inner_activation='sigmoid',
#                   output_mode='error', return_sequences=True, extrap_start_time=2)
#
# inputs = Input(shape=(nt,) + input_shape)
# errors = prednet(inputs)  # errors will be (batch_size, nt, nb_layers)
# errors_by_time = TimeDistributed(Dense(1, trainable=False), weights=[layer_loss_weights, np.zeros(1)], trainable=False)(errors)  # calculate weighted error by layer
# errors_by_time = Flatten()(errors_by_time)  # will be (batch_size, nt)
# final_errors = Dense(1, weights=[time_loss_weights, np.zeros(1)], trainable=False)(errors_by_time)  # weight errors by time
# outputs = final_errors
# # outputs = np.empty(shape=(nt,) + input_shape)
# # for i in range(nt):
# #     temp_outputs = prednet(inputs)
# #     outputs[i] = temp_outputs
# #     for j in range(nt - 1):
# #         inputs[j] = inputs[j + 1]
# #     inputs[-1] = temp_outputs
#
# def my_loss(y_true, y_pred):
# #     w = tf.add(y_true, tf.constant(0.5))
# #     w = tf.add(y_pred, w)
# #     loss = tf.losses.mean_squared_error(y_true, y_pred, weights=w)
# #     loss = tf.losses.mean_squared_error(y_true, y_pred)
#     loss = tf.losses.absolute_difference(y_true, y_pred)
# #     loss = tf.multiply(loss, tf.constant(1000000000.0))
#     return loss
#
# model = keras.models.Model(inputs=inputs, outputs=outputs)
# model.compile(loss=my_loss, optimizer=keras.optimizers.Adam())
# print(time.strftime('build time: %Y-%m-%d %H:%M:%S', time.localtime()))
# 7e-5
# ```

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 6, 256, 256, 3)    0
# _________________________________________________________________
# pred_net_1 (PredNet)         (None, 6, 4)              6915948
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 6, 1)              5
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 6,915,960
# Trainable params: 6,915,948
# Non-trainable params: 12
# _________________________________________________________________

# %% [markdown]
# how to use tensorboard
#
# ```bash
# jupyter notebook --ip=192.168.2.101
# python3 /usr/local/lib/python3.5/dist-packages/tensorboard/main.py --logdir='/home/hadoop/Documents/Neutrino/tensorboard_logs' --host=192.168.2.101 --port=8900
# rm -rf /home/hadoop/Documents/Neutrino/tensorboard_logs
# scp "C:/Users/Administrator/Downloads/SRAD2018_Test_1.zip" hadoop@192.168.1.115:~/Documents/Neutrino/SRAD2018/SRAD2018_test
# mv -v ~/Documents/Neutrino/SRAD2018/SRAD2018_test/SRAD2018_Test_1* ~/Documents/Neutrino/SRAD2018/SRAD2018_test
# lsof /dev/nvidia0
# lsof -n -i4TCP:8888
# kill -9 -[PID]
# ```
#
# `http://222.200.177.32:8900/#scalars&run=.&_smoothingWeight=0.8`
#
# `http://222.200.177.32:8888`

# %%
lr_schedule = lambda epoch: 0.001 if epoch < 20 else 0.0003    # start with lr of 0.001 and then drop to 0.0001 after 75 epochs
tb_callback = keras.callbacks.TensorBoard(log_dir='/home/hadoop/Documents/Neutrino/tensorboard_logs', histogram_freq=0, write_graph=False)
callbacks = [LearningRateScheduler(lr_schedule), tb_callback]

# %%
start_time = time.time()
print(time.strftime('start time: %Y-%m-%d %H:%M:%S', time.localtime()))
train_generator = trainGenerator(list_IDs=RAD_id_list[-4:-3], nt=nt, image_size=image_size, image_scalar=image_scalar, batch_size=1)
valid_generator = trainGenerator(list_IDs=RAD_id_list[:12], nt=nt, image_size=image_size, image_scalar=image_scalar, batch_size=1, shuffle=False)
# history = model.fit_generator(train_generator, steps_per_epoch=30, epochs=50, validation_data=valid_generator, validation_steps=12, use_multiprocessing=True, max_queue_size=20, callbacks=callbacks)
print(time.strftime('end time: %Y-%m-%d %H:%M:%S', time.localtime()))
print(time.strftime('It took  %H:%M:%S', time.gmtime(time.time() - start_time)))

# %%
for data in [train_generator, valid_generator][1]:
    x, y_ = data
    break

# %%
for i in range(6):
    for c in range(3):
        print(i, c)
        plt.imshow(np.rollaxis(x[0][i], 2, 0)[c] * image_scalar, cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
        plt.show()

# %%
lr_schedule = lambda epoch: 0.0003 if epoch < 20 else 0.00001    # start with lr of 0.001 and then drop to 0.0001 after 75 epochs
tb_callback = keras.callbacks.TensorBoard(log_dir='/home/hadoop/Documents/Neutrino/tensorboard_logs', histogram_freq=0, write_graph=False)
callbacks = [LearningRateScheduler(lr_schedule), tb_callback]

# %%
print(time.strftime('start time: %Y-%m-%d %H:%M:%S', time.localtime()))
start_time = time.time()
train_generator = trainGenerator(list_IDs=RAD_id_list[:6000], nt=nt, image_size=image_size, image_scalar=image_scalar, batch_size=1)
valid_generator = trainGenerator(list_IDs=RAD_id_list[-20:], nt=nt, image_size=image_size, image_scalar=image_scalar, batch_size=1)
history = model.fit_generator(train_generator, steps_per_epoch=100, epochs=200, validation_data=valid_generator, validation_steps=20, callbacks=callbacks)
print(time.strftime('end time: %Y-%m-%d %H:%M:%S', time.localtime()))
print(time.strftime('It took  %H:%M:%S', time.gmtime(time.time() - start_time)))
# Out:
# start time: 2018-09-07 01:55:02
# Epoch 1/200
# 100/100 [==============================] - 31s 315ms/step - loss: 1.3948e-04 - val_loss: 1.1220e-04
# Epoch 2/200
# 100/100 [==============================] - 32s 322ms/step - loss: 1.0933e-04 - val_loss: 9.3227e-05
# Epoch 3/200
# 100/100 [==============================] - 31s 314ms/step - loss: 9.1612e-05 - val_loss: 1.0562e-04
# Epoch 4/200
# 100/100 [==============================] - 32s 316ms/step - loss: 8.6328e-05 - val_loss: 8.2244e-05
# Epoch 5/200
# 100/100 [==============================] - 31s 314ms/step - loss: 7.7902e-05 - val_loss: 8.3508e-05
# Epoch 6/200
# 100/100 [==============================] - 31s 313ms/step - loss: 8.7768e-05 - val_loss: 8.5453e-05
# Epoch 7/200
# 100/100 [==============================] - 31s 312ms/step - loss: 8.4612e-05 - val_loss: 8.4853e-05
# Epoch 8/200
# 100/100 [==============================] - 31s 311ms/step - loss: 8.8910e-05 - val_loss: 7.6654e-05
# Epoch 9/200
# 100/100 [==============================] - 31s 311ms/step - loss: 8.2240e-05 - val_loss: 8.4596e-05
# Epoch 10/200
# 100/100 [==============================] - 31s 310ms/step - loss: 7.4544e-05 - val_loss: 8.0164e-05
# Epoch 11/200
# 100/100 [==============================] - 31s 308ms/step - loss: 9.8325e-05 - val_loss: 9.4718e-05
# Epoch 12/200
# 100/100 [==============================] - 31s 308ms/step - loss: 7.6162e-05 - val_loss: 7.7596e-05
# Epoch 13/200
# 100/100 [==============================] - 31s 308ms/step - loss: 7.5063e-05 - val_loss: 8.3690e-05
# Epoch 14/200
# 100/100 [==============================] - 31s 307ms/step - loss: 8.5261e-05 - val_loss: 8.1009e-05
# Epoch 15/200
# 100/100 [==============================] - 31s 307ms/step - loss: 7.8465e-05 - val_loss: 7.9822e-05
# Epoch 16/200
# 100/100 [==============================] - 31s 308ms/step - loss: 8.1788e-05 - val_loss: 7.1142e-05
# Epoch 17/200
# 100/100 [==============================] - 31s 308ms/step - loss: 8.0197e-05 - val_loss: 8.1208e-05
# Epoch 18/200
# 100/100 [==============================] - 31s 305ms/step - loss: 7.5418e-05 - val_loss: 7.3812e-05
# Epoch 19/200
# 100/100 [==============================] - 31s 307ms/step - loss: 7.7937e-05 - val_loss: 7.9814e-05
# Epoch 20/200
# 100/100 [==============================] - 31s 306ms/step - loss: 7.0624e-05 - val_loss: 7.3154e-05
# Epoch 21/200
# 100/100 [==============================] - 31s 305ms/step - loss: 7.4321e-05 - val_loss: 7.4282e-05
# Epoch 22/200
# 100/100 [==============================] - 31s 307ms/step - loss: 9.3772e-05 - val_loss: 7.9740e-05
# Epoch 23/200
# 100/100 [==============================] - 31s 307ms/step - loss: 7.5174e-05 - val_loss: 7.4458e-05
# Epoch 24/200
# 100/100 [==============================] - 31s 307ms/step - loss: 7.6995e-05 - val_loss: 7.1041e-05
# Epoch 25/200
# 100/100 [==============================] - 31s 307ms/step - loss: 8.5703e-05 - val_loss: 7.7805e-05
# Epoch 26/200
# 100/100 [==============================] - 31s 306ms/step - loss: 7.9719e-05 - val_loss: 7.4157e-05
# Epoch 27/200
# 100/100 [==============================] - 31s 306ms/step - loss: 6.3062e-05 - val_loss: 7.7527e-05
# Epoch 28/200
# 100/100 [==============================] - 31s 306ms/step - loss: 8.1285e-05 - val_loss: 7.5328e-05
# Epoch 29/200
# 100/100 [==============================] - 31s 305ms/step - loss: 6.8153e-05 - val_loss: 7.8166e-05
# Epoch 30/200
# 100/100 [==============================] - 31s 305ms/step - loss: 7.4894e-05 - val_loss: 7.8908e-05
# Epoch 31/200
# 100/100 [==============================] - 30s 304ms/step - loss: 6.3999e-05 - val_loss: 7.4848e-05
# Epoch 32/200
# 100/100 [==============================] - 30s 305ms/step - loss: 6.6378e-05 - val_loss: 7.2216e-05
# Epoch 33/200
#  28/100 [=======>......................] - ETA: 20s - loss: 5.6968e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-341c0af36a57> in <module>()
#       3 train_generator = trainGenerator(list_IDs=RAD_id_list[:6000], nt=nt, image_size=image_size, image_scalar=image_scalar, batch_size=1)
#       4 valid_generator = trainGenerator(list_IDs=RAD_id_list[-20:], nt=nt, image_size=image_size, image_scalar=image_scalar, batch_size=1)
# ----> 5 history = model.fit_generator(train_generator, steps_per_epoch=100, epochs=200, validation_data=valid_generator, validation_steps=20, callbacks=callbacks)
#       6 print(time.strftime('end time: %Y-%m-%d %H:%M:%S', time.localtime()))
#       7 print(time.strftime('It took  %H:%M:%S', time.gmtime(time.time() - start_time)))
#
# ~/.local/lib/python3.5/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/.local/lib/python3.5/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1413             use_multiprocessing=use_multiprocessing,
#    1414             shuffle=shuffle,
# -> 1415             initial_epoch=initial_epoch)
#    1416
#    1417     @interfaces.legacy_generator_methods_support
#
# ~/.local/lib/python3.5/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     211                 outs = model.train_on_batch(x, y,
#     212                                             sample_weight=sample_weight,
# --> 213                                             class_weight=class_weight)
#     214
#     215                 outs = to_list(outs)
#
# ~/.local/lib/python3.5/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1213             ins = x + y + sample_weights
#    1214         self._make_train_function()
# -> 1215         outputs = self.train_function(ins)
#    1216         return unpack_singleton(outputs)
#    1217
#
# ~/.local/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2670                     'In order to feed symbolic tensors to a Keras model '
#    2671                     'in TensorFlow, you need tensorflow 1.8 or higher.')
# -> 2672             return self._legacy_call(inputs)
#    2673
#    2674
#
# ~/.local/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in _legacy_call(self, inputs)
#    2652         session = get_session()
#    2653         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2654                               **self.session_kwargs)
#    2655         return updated[:len(self.outputs)]
#    2656
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1135     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1136       results = self._do_run(handle, final_targets, final_fetches,
# -> 1137                              feed_dict_tensor, options, run_metadata)
#    1138     else:
#    1139       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1353     if handle is None:
#    1354       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1355                            options, run_metadata)
#    1356     else:
#    1357       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1359   def _do_call(self, fn, *args):
#    1360     try:
# -> 1361       return fn(*args)
#    1362     except errors.OpError as e:
#    1363       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1338         else:
#    1339           return tf_session.TF_Run(session, options, feed_dict, fetch_list,
# -> 1340                                    target_list, status, run_metadata)
#    1341
#    1342     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
# Process ForkPoolWorker-65:
# Process ForkPoolWorker-67:
# Process ForkPoolWorker-68:
# Process ForkPoolWorker-69:
# Process ForkPoolWorker-66:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt

# %%
print(time.strftime('start time: %Y-%m-%d %H:%M:%S', time.localtime()))
start_time = time.time()
train_generator = trainGenerator(list_IDs=RAD_id_list[:6000], nt=nt, image_size=image_size, image_scalar=image_scalar, batch_size=5)
valid_generator = trainGenerator(list_IDs=RAD_id_list[-20:], nt=nt, image_size=image_size, image_scalar=image_scalar, batch_size=5)
history = model.fit_generator(train_generator, steps_per_epoch=20, epochs=50, validation_data=valid_generator, validation_steps=20, callbacks=callbacks)
print(time.strftime('end time: %Y-%m-%d %H:%M:%S', time.localtime()))
print(time.strftime('It took  %H:%M:%S', time.gmtime(time.time() - start_time)))

# %% [markdown]
# ## 保存模型

# %%
version = 'SRAD2018_Neutrino_PredNet_v0.4.1.1_18.09.07.01.07'
model.save('/home/hadoop/Documents/Neutrino/prednet/%s.hdf5' % version)
model.save_weights('/home/hadoop/Documents/Neutrino/prednet/%s_weights.hdf5' % version)

# %%
model.load_weights()

# %% [markdown]
# ## `return_sequences=False`

# %%
train_model = model
layer_config = train_model.layers[1].get_config()
layer_config['output_mode'] = 'prediction'
layer_config['return_sequences'] = False
data_format = layer_config['data_format'] if 'data_format' in layer_config else layer_config['dim_ordering']
test_prednet = PredNet(weights=train_model.layers[1].get_weights(), **layer_config)

# %%
test_inputs = Input(shape=(nt,) + input_shape)
test_outputs = test_prednet(test_inputs)

def my_loss(y_true, y_pred):
#     w = tf.add(y_true, tf.constant(0.8))
#     w = tf.add(y_pred, w)
#     loss = tf.losses.mean_squared_error(y_true, y_pred, weights=w)
    loss = tf.losses.mean_squared_error(y_true, y_pred)
    loss = tf.multiply(loss, tf.constant(10000000.0))
    return loss

test_model = keras.models.Model(inputs=test_inputs, outputs=test_outputs)
test_model.compile(loss=my_loss, optimizer=keras.optimizers.Adam())
print(time.strftime('build time: %Y-%m-%d %H:%M:%S', time.localtime()))
# Out:
# build time: 2018-09-07 02:11:46

# %%
class testGenerator(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, nt, image_size, image_scalar, batch_size=32, shuffle=True):
        'Initialization'
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.shuffle = shuffle
        self.nt = nt
        self.image_size = image_size
        self.image_scalar = image_scalar
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        # Find list of IDs
        list_IDs_temp = [self.list_IDs[k] for k in indexes]
        # Generate data
        X, y = self.__data_generation(list_IDs_temp)
        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, list_IDs_temp):
        X, y = data_generation(list_IDs_temp, batch_size=self.batch_size, image_size=self.image_size, nt=self.nt, step_size=step_size, image_scalar=self.image_scalar)
        y = np.zeros(self.batch_size, np.float32)
        return X, y
print(time.strftime('build time: %Y-%m-%d %H:%M:%S', time.localtime()))
# Out:
# build time: 2018-09-07 02:11:46

# %%
print(time.strftime('start time: %Y-%m-%d %H:%M:%S', time.localtime()))
train_generator = testGenerator(list_IDs=RAD_id_list[:1], nt=nt, image_size=image_size, image_scalar=image_scalar, batch_size=1)
valid_generator = testGenerator(list_IDs=RAD_id_list[-4:-3], nt=nt, image_size=image_size, image_scalar=image_scalar, batch_size=1)
# Out:
# start time: 2018-09-07 02:11:46

# %%
x.shape

# %%
a = np.rollaxis(x[0][5], 2, 0)[c].ravel()

# %%
sns.distplot(a)

# %%
for data in [train_generator, valid_generator][0]:
    x, y_ = data
    break
c = 0
for i in range(6):
    plt.imshow(np.rollaxis(x[0][i], 2, 0)[c] * image_scalar, cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
    plt.show()

# %%
# train_generator.on_epoch_end()
# valid_generator.on_epoch_end()
for data in [train_generator, valid_generator][0]:
    x, y_ = data
    break
for i in range(30 // step_size):
    y = test_model.predict(x)
#     temp_matrix = np.rollaxis(y[0], 2, 0)
#     for k in range(3):
#         psf_size = 15
#         psf = np.ones((psf_size, psf_size)) / psf_size ** 2
#         temp_matrix[k] = restoration.wiener(temp_matrix[k], psf, 5)
#     y[0] = np.rollaxis(temp_matrix, 0, 3)
    y = np.where(y<0.03, -0.01, y)
#     y = np.where(y>0.6, 0.6, y)
    for j in range(nt - 1):
        x[0][j] = x[0][j + 1]
    x[0][-1] = y[0]
    for k in range(n_channels):
        print(i, k)
        plt.imshow(np.rollaxis(y[0], 2, 0)[k] * image_scalar, cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
        plt.show()
# Out:
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2
# 2 0
# 2 1
# 2 2
# 3 0
# 3 1
# 3 2
# 4 0
# 4 1
# 4 2
# 5 0
# 5 1
# 5 2

# %%
a = np.rollaxis(y[0], 2, 0)[0]

# %%
a = y_pred_last

# %%
plt.imshow(x_last, cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
plt.show()
plt.imshow(a * 1.5, cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
plt.show()

# %%
psf_size = 15
psf = np.ones((psf_size, psf_size)) / (psf_size ** 2)
b = restoration.wiener(a, psf, 10)
# b = a
plt.imshow(b * image_scalar, cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
plt.show()

# %%
arr = x_last.ravel()
d1 = np.delete(arr, np.where(arr<0))
sns.distplot(d1)
plt.show
arr = y_pred_last.ravel()
# arr = arr * 2
d2 = np.delete(arr, np.where(arr<0))
sns.distplot(d2)
plt.show()

# %%
print(len(d1))
print(len(d2))
# Out:
# 5778
# 10695

# %%
d1.sort()

# %%
def foo(x):
    return [x//2, x%2]

# %%
a = np.array([[10, 13], [11, 21], [17, 18]])
b = np.argsort(a, axis=None)#.reshape(a.shape)

# %%
b#.reshape(a.shape)
# Out:
# array([0, 2, 1, 4, 5, 3])

# %%
a.ravel().reshape(a.shape)
# Out:
# array([[10, 13],
#        [21, 21],
#        [17, 18]])

# %%
e = copy.deepcopy(x_last)
a = copy.deepcopy(y_pred_last)
b = np.argsort(a, axis=None)
c = np.empty(a.shape)
c = c.ravel()
d = a.ravel()
for i in range(c.shape[0]):
    c[i] = d[b[i]]
c = c.reshape(a.shape)

# %%
plt.imshow(c, cmap=cm.gist_ncar_r)
plt.show()

# %%
a.shape
# Out:
# (256, 256)

# %%
c = np.empty(a.shape)
for i in range(c.shape[0]):
    for j in range(c.shape[1]):
        print(i, j)
        c[i][j] = b[i][j]
# Out:
# 0 0
# 0 1
# 1 0
# 1 1
# 2 0
# 2 1

# %%
# %time
np.where(a==0, 0, c)
# Out:
# CPU times: user 6 µs, sys: 1e+03 ns, total: 7 µs
# Wall time: 16.2 µs
# array([[4., 5.],
#        [3., 1.],
#        [0., 0.]])

# %%
cv2.equalizeHist()

# %%
start_time = time.time()
print(time.strftime("start time: %Y-%m-%d %H:%M:%S", time.localtime()))
model_loss = []
last_frame_loss = []
for RAD_id_counter, RAD_id in enumerate(RAD_id_list[-50:]):
    x, y = data_generation([RAD_id], batch_size=1, image_size=image_size, image_scalar=image_scalar, nt=nt, step_size=step_size, offset=60-nt*step_size)
    for i in range(30 // step_size):
        y = test_model.predict(x)
#         temp_matrix = np.rollaxis(y[0], 2, 0)
#         for k in range(3):
#             psf_size = 15
#             psf = np.ones((psf_size, psf_size)) / psf_size ** 2
#             temp_matrix[k] = restoration.wiener(temp_matrix[k], psf, 10)
#         y[0] = np.rollaxis(temp_matrix, 0, 3)
        y = np.where(y<0.03, -0.01, y)
    #     y = np.where(y>0.6, 0.6, y)
        for j in range(nt - 1):
            x[0][j] = x[0][j + 1]
        x[0][-1] = y[0]
    x, y = x[0], y[0]
    x_last = np.array(PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png" % (RAD_id, RAD_id, 30)).resize((image_size, image_size))).astype(np.int8).reshape((image_size, image_size))
    y_true_last = np.array(PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_train/%s/%s_%03d.png" % (RAD_id, RAD_id, 60)).resize((image_size, image_size))).astype(np.int8).reshape((image_size, image_size))
    y_pred_last = np.rollaxis(y, 2, 0)[0] * image_scalar + np.rollaxis(y, 2, 0)[1] * image_scalar + np.rollaxis(y, 2, 0)[2] * image_scalar# + np.rollaxis(y, 2, 0)[3] * image_scalar
    y_pred_last = y_pred_last / 3
#     last_frame_loss.append(sklearn.metrics.mean_absolute_error(y_true_last, x_last))
#     model_loss.append(sklearn.metrics.mean_absolute_error(y_true_last, y_pred_last))
    last_frame_loss.append(sklearn.metrics.mean_squared_error(y_true_last, x_last))
    model_loss.append(sklearn.metrics.mean_squared_error(y_true_last, y_pred_last))
    if RAD_id_counter % 10 == 0:
        print('RAD_id_counter=%5d\t\tIt takes %.2f' % (RAD_id_counter, time.time() - start_time))
model_loss = np.array(model_loss)
last_frame_loss = np.array(last_frame_loss)
print('     model_loss=%.7f' % model_loss.mean())
print('last_frame_loss=%.7f' % last_frame_loss.mean())
print(time.strftime('It took  %H:%M:%S', time.gmtime(time.time() - start_time)))
print(time.strftime("end time: %Y-%m-%d %H:%M:%S", time.localtime()))
# Out:
# start time: 2018-09-07 02:11:57
# RAD_id_counter=    0		It takes 0.51
# RAD_id_counter=   10		It takes 5.58
# RAD_id_counter=   20		It takes 10.67
# RAD_id_counter=   30		It takes 15.74
# RAD_id_counter=   40		It takes 20.83
#      model_loss=15.6464329
# last_frame_loss=3.4866873
# It took  00:00:25
# end time: 2018-09-07 02:12:22

# %% [markdown]
# 15.3290176 0
# 15.3366709 1
# 15.2775345 2
# 15.2723169 average

# %%
y.shape

# %%
plt.imshow(x_last.reshape((image_size, image_size)), cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
plt.show()
plt.imshow(y_true_last.reshape((image_size, image_size)), cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
plt.show()
plt.imshow(y_pred_last.reshape((image_size, image_size)), cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
plt.show()

# %% [markdown]
# # 用模型预测数据

# %%
RAD_id_submit_list = os.listdir("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_test/")
print(len(RAD_id_submit_list))
# Out:
# 10000

# %%
RAD_id = RAD_id_submit_list[12]

# %%
x, y = data_generation([RAD_id], batch_size=1, image_size=image_size, image_scalar=image_scalar, nt=nt, step_size=step_size, offset=0, path='/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_test')

for i in range(30 // step_size):
    y = test_model.predict(x)
#     temp_matrix = np.rollaxis(y[0], 2, 0)
#     for k in range(3):
#         psf_size = 15
#         psf = np.ones((psf_size, psf_size)) / psf_size ** 2
#         temp_matrix[k] = restoration.wiener(temp_matrix[k], psf, 5)
#     y[0] = np.rollaxis(temp_matrix, 0, 3)
    y = np.where(y<0.03, -0.01, y)
#     y = np.where(y>0.6, 0.6, y)
    for j in range(nt - 1):
        x[0][j] = x[0][j + 1]
    x[0][-1] = y[0]
    for k in range(n_channels):
        print(i, k)
        plt.imshow(np.rollaxis(y[0], 2, 0)[k] * image_scalar, cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
        plt.show()
# Out:
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2
# 2 0
# 2 1
# 2 2
# 3 0
# 3 1
# 3 2
# 4 0
# 4 1
# 4 2
# 5 0
# 5 1
# 5 2

# %%
np.rollaxis(y[0], 2, 0)[k].shape
# Out:
# (256, 256)

# %%
version = 'SRAD2018_submit_Neutrino_PredNet_v0.4.1.0_18.09.07.02.07'
start_time = time.time()
print(time.strftime("start time: %Y-%m-%d %H:%M:%S", time.localtime()))
for RAD_id_counter, RAD_id in enumerate(RAD_id_submit_list):
    x, y = data_generation([RAD_id], batch_size=1, image_size=image_size, image_scalar=image_scalar, nt=nt, step_size=step_size, offset=0, path='/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_test')
    if not os.path.exists("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_submit/%s/%s" % (version, RAD_id)):
        os.makedirs("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_submit/%s/%s" % (version, RAD_id))
    for i in range(30 // step_size):
        y = test_model.predict(x)
    #     temp_matrix = np.rollaxis(y[0], 2, 0)
    #     for k in range(3):
    #         psf_size = 15
    #         psf = np.ones((psf_size, psf_size)) / psf_size ** 2
    #         temp_matrix[k] = restoration.wiener(temp_matrix[k], psf, 5)
    #     y[0] = np.rollaxis(temp_matrix, 0, 3)
        y = np.where(y<0.03, -0.01, y)
        y = np.where(y>0.33, 0.33, y)
        for j in range(nt - 1):
            x[0][j] = x[0][j + 1]
        x[0][-1] = y[0]
        result = np.empty((image_size, image_size))
        for k in range(n_channels):
#             print(i, k)
            result = result + np.rollaxis(y[0], 2, 0)[k] * image_scalar
#             plt.imshow(np.rollaxis(y[0], 2, 0)[k] * image_scalar, cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
#             plt.show()
        result = result / 3
#         print(i)
#         plt.imshow(result, cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
#         plt.show()
        result = result.astype(np.uint8)
        result = np.where(result==0, 255, result)
        result = PIL.Image.fromarray(result)
        result = result.resize((501, 501))
#         plt.imshow(result, cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
#         plt.show()
        result.save("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_submit/%s/%s/%s_f%03d.png" % (version, RAD_id, RAD_id, i))
    if RAD_id_counter % 10 == 0:
        print('RAD_id_counter=%5d\t\tIt takes %.2f' % (RAD_id_counter, time.time() - start_time))
print(time.strftime('It took  %H:%M:%S', time.gmtime(time.time() - start_time)))
print(time.strftime("end time: %Y-%m-%d %H:%M:%S", time.localtime()))
# Out:
# start time: 2018-09-07 02:24:21
# RAD_id_counter=    0		It takes 0.53
# RAD_id_counter=   10		It takes 5.96
# RAD_id_counter=   20		It takes 11.39
# RAD_id_counter=   30		It takes 16.82
# RAD_id_counter=   40		It takes 22.22
# RAD_id_counter=   50		It takes 27.70
# RAD_id_counter=   60		It takes 33.12
# RAD_id_counter=   70		It takes 38.58
# RAD_id_counter=   80		It takes 44.25
# RAD_id_counter=   90		It takes 50.10
# RAD_id_counter=  100		It takes 55.90
# RAD_id_counter=  110		It takes 61.57
# RAD_id_counter=  120		It takes 67.21
# RAD_id_counter=  130		It takes 72.81
# RAD_id_counter=  140		It takes 78.49
# RAD_id_counter=  150		It takes 84.14
# RAD_id_counter=  160		It takes 89.84
# RAD_id_counter=  170		It takes 95.58
# RAD_id_counter=  180		It takes 101.19
# RAD_id_counter=  190		It takes 106.85
# RAD_id_counter=  200		It takes 112.46
# RAD_id_counter=  210		It takes 118.11
# RAD_id_counter=  220		It takes 123.75
# RAD_id_counter=  230		It takes 129.35
# RAD_id_counter=  240		It takes 135.04
# RAD_id_counter=  250		It takes 140.70
# RAD_id_counter=  260		It takes 146.40
# RAD_id_counter=  270		It takes 152.07
# RAD_id_counter=  280		It takes 157.71
# RAD_id_counter=  290		It takes 163.37
# RAD_id_counter=  300		It takes 168.99
# RAD_id_counter=  310		It takes 174.64
# RAD_id_counter=  320		It takes 180.32
# RAD_id_counter=  330		It takes 185.95
# RAD_id_counter=  340		It takes 191.52
# RAD_id_counter=  350		It takes 197.14
# RAD_id_counter=  360		It takes 202.81
# RAD_id_counter=  370		It takes 208.49
# RAD_id_counter=  380		It takes 214.12
# RAD_id_counter=  390		It takes 219.70
# RAD_id_counter=  400		It takes 225.33
# RAD_id_counter=  410		It takes 230.96
# RAD_id_counter=  420		It takes 236.51
# RAD_id_counter=  430		It takes 242.04
# RAD_id_counter=  440		It takes 247.61
# RAD_id_counter=  450		It takes 253.24
# RAD_id_counter=  460		It takes 258.82
# RAD_id_counter=  470		It takes 264.42
# RAD_id_counter=  480		It takes 269.98
# RAD_id_counter=  490		It takes 275.63
# RAD_id_counter=  500		It takes 281.21
# RAD_id_counter=  510		It takes 286.75
# RAD_id_counter=  520		It takes 292.38
# RAD_id_counter=  530		It takes 297.95
# RAD_id_counter=  540		It takes 303.57
# RAD_id_counter=  550		It takes 309.17
# RAD_id_counter=  560		It takes 314.74
# RAD_id_counter=  570		It takes 320.29
# RAD_id_counter=  580		It takes 325.85
# RAD_id_counter=  590		It takes 331.42
# RAD_id_counter=  600		It takes 336.95
# RAD_id_counter=  610		It takes 342.47
# RAD_id_counter=  620		It takes 348.08
# RAD_id_counter=  630		It takes 353.63
# RAD_id_counter=  640		It takes 359.19
# RAD_id_counter=  650		It takes 364.85
# RAD_id_counter=  660		It takes 370.41
# RAD_id_counter=  670		It takes 375.94
# RAD_id_counter=  680		It takes 381.50
# RAD_id_counter=  690		It takes 386.99
# RAD_id_counter=  700		It takes 392.50
# RAD_id_counter=  710		It takes 398.03
# RAD_id_counter=  720		It takes 403.61
# RAD_id_counter=  730		It takes 409.15
# RAD_id_counter=  740		It takes 414.68
# RAD_id_counter=  750		It takes 420.19
# RAD_id_counter=  760		It takes 425.73
# RAD_id_counter=  770		It takes 431.28
# RAD_id_counter=  780		It takes 436.83
# RAD_id_counter=  790		It takes 442.39
# RAD_id_counter=  800		It takes 447.94
# RAD_id_counter=  810		It takes 453.54
# RAD_id_counter=  820		It takes 459.10
# RAD_id_counter=  830		It takes 464.60
# RAD_id_counter=  840		It takes 470.11
# RAD_id_counter=  850		It takes 475.62
# RAD_id_counter=  860		It takes 481.11
# RAD_id_counter=  870		It takes 486.59
# RAD_id_counter=  880		It takes 492.19
# RAD_id_counter=  890		It takes 497.72
# RAD_id_counter=  900		It takes 503.26
# RAD_id_counter=  910		It takes 508.78
# RAD_id_counter=  920		It takes 514.35
# RAD_id_counter=  930		It takes 519.88
# RAD_id_counter=  940		It takes 525.40
# RAD_id_counter=  950		It takes 530.93
# RAD_id_counter=  960		It takes 536.48
# RAD_id_counter=  970		It takes 542.05
# RAD_id_counter=  980		It takes 547.63
# RAD_id_counter=  990		It takes 553.11
# RAD_id_counter= 1000		It takes 558.62
# RAD_id_counter= 1010		It takes 564.21
# RAD_id_counter= 1020		It takes 569.77
# RAD_id_counter= 1030		It takes 575.26
# RAD_id_counter= 1040		It takes 580.81
# RAD_id_counter= 1050		It takes 586.35
# RAD_id_counter= 1060		It takes 591.90
# RAD_id_counter= 1070		It takes 597.47
# RAD_id_counter= 1080		It takes 603.01
# RAD_id_counter= 1090		It takes 608.55
# RAD_id_counter= 1100		It takes 614.09
# RAD_id_counter= 1110		It takes 619.62
# RAD_id_counter= 1120		It takes 625.15
# RAD_id_counter= 1130		It takes 630.65
# RAD_id_counter= 1140		It takes 636.25
# RAD_id_counter= 1150		It takes 641.82
# RAD_id_counter= 1160		It takes 647.38
# RAD_id_counter= 1170		It takes 652.83
# RAD_id_counter= 1180		It takes 658.40
# RAD_id_counter= 1190		It takes 664.00
# RAD_id_counter= 1200		It takes 669.54
# RAD_id_counter= 1210		It takes 675.08
# RAD_id_counter= 1220		It takes 680.60
# RAD_id_counter= 1230		It takes 686.14
# RAD_id_counter= 1240		It takes 691.65
# RAD_id_counter= 1250		It takes 697.14
# RAD_id_counter= 1260		It takes 702.70
# RAD_id_counter= 1270		It takes 708.21
# RAD_id_counter= 1280		It takes 713.73
# RAD_id_counter= 1290		It takes 719.27
# RAD_id_counter= 1300		It takes 724.86
# RAD_id_counter= 1310		It takes 730.35
# RAD_id_counter= 1320		It takes 735.88
# RAD_id_counter= 1330		It takes 741.41
# RAD_id_counter= 1340		It takes 746.95
# RAD_id_counter= 1350		It takes 752.45
# RAD_id_counter= 1360		It takes 757.98
# RAD_id_counter= 1370		It takes 763.58
# RAD_id_counter= 1380		It takes 769.11
# RAD_id_counter= 1390		It takes 774.63
# RAD_id_counter= 1400		It takes 780.16
# RAD_id_counter= 1410		It takes 785.74
# RAD_id_counter= 1420		It takes 791.25
# RAD_id_counter= 1430		It takes 796.73
# RAD_id_counter= 1440		It takes 802.18
# RAD_id_counter= 1450		It takes 807.71
# RAD_id_counter= 1460		It takes 813.21
# RAD_id_counter= 1470		It takes 818.69
# RAD_id_counter= 1480		It takes 824.13
# RAD_id_counter= 1490		It takes 829.62
# RAD_id_counter= 1500		It takes 835.15
# RAD_id_counter= 1510		It takes 840.61
# RAD_id_counter= 1520		It takes 846.12
# RAD_id_counter= 1530		It takes 851.63
# RAD_id_counter= 1540		It takes 857.11
# RAD_id_counter= 1550		It takes 862.61
# RAD_id_counter= 1560		It takes 868.07
# RAD_id_counter= 1570		It takes 873.53
# RAD_id_counter= 1580		It takes 879.03
# RAD_id_counter= 1590		It takes 884.55
# RAD_id_counter= 1600		It takes 890.01
# RAD_id_counter= 1610		It takes 895.50
# RAD_id_counter= 1620		It takes 900.94
# RAD_id_counter= 1630		It takes 906.42
# RAD_id_counter= 1640		It takes 911.88
# RAD_id_counter= 1650		It takes 917.40
# RAD_id_counter= 1660		It takes 922.86
# RAD_id_counter= 1670		It takes 928.31
# RAD_id_counter= 1680		It takes 933.81
# RAD_id_counter= 1690		It takes 939.31
# RAD_id_counter= 1700		It takes 944.85
# RAD_id_counter= 1710		It takes 950.37
# RAD_id_counter= 1720		It takes 955.87
# RAD_id_counter= 1730		It takes 961.33
# RAD_id_counter= 1740		It takes 966.80
# RAD_id_counter= 1750		It takes 972.27
# RAD_id_counter= 1760		It takes 977.82
# RAD_id_counter= 1770		It takes 983.29
# RAD_id_counter= 1780		It takes 988.74
# RAD_id_counter= 1790		It takes 994.26
# RAD_id_counter= 1800		It takes 999.76
# RAD_id_counter= 1810		It takes 1005.20
# RAD_id_counter= 1820		It takes 1010.75
# RAD_id_counter= 1830		It takes 1016.26
# RAD_id_counter= 1840		It takes 1021.75
# RAD_id_counter= 1850		It takes 1027.21
# RAD_id_counter= 1860		It takes 1032.73
# RAD_id_counter= 1870		It takes 1038.21
# RAD_id_counter= 1880		It takes 1043.71
# RAD_id_counter= 1890		It takes 1049.19
# RAD_id_counter= 1900		It takes 1054.67
# RAD_id_counter= 1910		It takes 1060.15
# RAD_id_counter= 1920		It takes 1065.68
# RAD_id_counter= 1930		It takes 1071.14
# RAD_id_counter= 1940		It takes 1076.60
# RAD_id_counter= 1950		It takes 1082.05
# RAD_id_counter= 1960		It takes 1087.53
# RAD_id_counter= 1970		It takes 1093.02
# RAD_id_counter= 1980		It takes 1098.53
# RAD_id_counter= 1990		It takes 1104.04
# RAD_id_counter= 2000		It takes 1109.50
# RAD_id_counter= 2010		It takes 1114.99
# RAD_id_counter= 2020		It takes 1120.47
# RAD_id_counter= 2030		It takes 1125.93
# RAD_id_counter= 2040		It takes 1131.39
# RAD_id_counter= 2050		It takes 1136.86
# RAD_id_counter= 2060		It takes 1142.35
# RAD_id_counter= 2070		It takes 1147.78
# RAD_id_counter= 2080		It takes 1153.28
# RAD_id_counter= 2090		It takes 1158.80
# RAD_id_counter= 2100		It takes 1164.28
# RAD_id_counter= 2110		It takes 1169.76
# RAD_id_counter= 2120		It takes 1175.30
# RAD_id_counter= 2130		It takes 1180.79
# RAD_id_counter= 2140		It takes 1186.25
# RAD_id_counter= 2150		It takes 1191.71
# RAD_id_counter= 2160		It takes 1197.23
# RAD_id_counter= 2170		It takes 1202.67
# RAD_id_counter= 2180		It takes 1208.25
# RAD_id_counter= 2190		It takes 1213.72
# RAD_id_counter= 2200		It takes 1219.21
# RAD_id_counter= 2210		It takes 1224.66
# RAD_id_counter= 2220		It takes 1230.17
# RAD_id_counter= 2230		It takes 1235.65
# RAD_id_counter= 2240		It takes 1241.14
# RAD_id_counter= 2250		It takes 1246.66
# RAD_id_counter= 2260		It takes 1252.16
# RAD_id_counter= 2270		It takes 1257.71
# RAD_id_counter= 2280		It takes 1263.22
# RAD_id_counter= 2290		It takes 1268.69
# RAD_id_counter= 2300		It takes 1274.22
# RAD_id_counter= 2310		It takes 1279.75
# RAD_id_counter= 2320		It takes 1285.23
# RAD_id_counter= 2330		It takes 1290.70
# RAD_id_counter= 2340		It takes 1296.20
# RAD_id_counter= 2350		It takes 1301.64
# RAD_id_counter= 2360		It takes 1307.11
# RAD_id_counter= 2370		It takes 1312.56
# RAD_id_counter= 2380		It takes 1318.08
# RAD_id_counter= 2390		It takes 1323.55
# RAD_id_counter= 2400		It takes 1329.01
# RAD_id_counter= 2410		It takes 1334.49
# RAD_id_counter= 2420		It takes 1339.94
# RAD_id_counter= 2430		It takes 1345.42
# RAD_id_counter= 2440		It takes 1350.92
# RAD_id_counter= 2450		It takes 1356.46
# RAD_id_counter= 2460		It takes 1361.93
# RAD_id_counter= 2470		It takes 1367.39
# RAD_id_counter= 2480		It takes 1372.86
# RAD_id_counter= 2490		It takes 1378.34
# RAD_id_counter= 2500		It takes 1383.82
# RAD_id_counter= 2510		It takes 1389.34
# RAD_id_counter= 2520		It takes 1394.78
# RAD_id_counter= 2530		It takes 1400.24
# RAD_id_counter= 2540		It takes 1405.77
# RAD_id_counter= 2550		It takes 1411.24
# RAD_id_counter= 2560		It takes 1416.70
# RAD_id_counter= 2570		It takes 1422.12
# RAD_id_counter= 2580		It takes 1427.55
# RAD_id_counter= 2590		It takes 1433.00
# RAD_id_counter= 2600		It takes 1438.50
# RAD_id_counter= 2610		It takes 1443.99
# RAD_id_counter= 2620		It takes 1449.54
# RAD_id_counter= 2630		It takes 1455.02
# RAD_id_counter= 2640		It takes 1460.51
# RAD_id_counter= 2650		It takes 1465.97
# RAD_id_counter= 2660		It takes 1471.44
# RAD_id_counter= 2670		It takes 1476.96
# RAD_id_counter= 2680		It takes 1482.47
# RAD_id_counter= 2690		It takes 1487.95
# RAD_id_counter= 2700		It takes 1493.43
# RAD_id_counter= 2710		It takes 1499.01
# RAD_id_counter= 2720		It takes 1504.48
# RAD_id_counter= 2730		It takes 1509.93
# RAD_id_counter= 2740		It takes 1515.42
# RAD_id_counter= 2750		It takes 1520.94
# RAD_id_counter= 2760		It takes 1526.36
# RAD_id_counter= 2770		It takes 1531.85
# RAD_id_counter= 2780		It takes 1537.32
# RAD_id_counter= 2790		It takes 1542.81
# RAD_id_counter= 2800		It takes 1548.33
# RAD_id_counter= 2810		It takes 1553.84
# RAD_id_counter= 2820		It takes 1559.36
# RAD_id_counter= 2830		It takes 1564.82
# RAD_id_counter= 2840		It takes 1570.35
# RAD_id_counter= 2850		It takes 1575.85
# RAD_id_counter= 2860		It takes 1581.38
# RAD_id_counter= 2870		It takes 1586.86
# RAD_id_counter= 2880		It takes 1592.35
# RAD_id_counter= 2890		It takes 1597.86
# RAD_id_counter= 2900		It takes 1603.36
# RAD_id_counter= 2910		It takes 1608.83
# RAD_id_counter= 2920		It takes 1614.27
# RAD_id_counter= 2930		It takes 1619.79
# RAD_id_counter= 2940		It takes 1625.25
# RAD_id_counter= 2950		It takes 1630.76
# RAD_id_counter= 2960		It takes 1636.33
# RAD_id_counter= 2970		It takes 1641.84
# RAD_id_counter= 2980		It takes 1647.28
# RAD_id_counter= 2990		It takes 1652.77
# RAD_id_counter= 3000		It takes 1658.29
# RAD_id_counter= 3010		It takes 1663.77
# RAD_id_counter= 3020		It takes 1669.29
# RAD_id_counter= 3030		It takes 1674.83
# RAD_id_counter= 3040		It takes 1680.36
# RAD_id_counter= 3050		It takes 1685.85
# RAD_id_counter= 3060		It takes 1691.30
# RAD_id_counter= 3070		It takes 1696.80
# RAD_id_counter= 3080		It takes 1702.35
# RAD_id_counter= 3090		It takes 1707.84
# RAD_id_counter= 3100		It takes 1713.30
# RAD_id_counter= 3110		It takes 1718.82
# RAD_id_counter= 3120		It takes 1724.32
# RAD_id_counter= 3130		It takes 1729.82
# RAD_id_counter= 3140		It takes 1735.34
# RAD_id_counter= 3150		It takes 1740.82
# RAD_id_counter= 3160		It takes 1746.28
# RAD_id_counter= 3170		It takes 1751.79
# RAD_id_counter= 3180		It takes 1757.30
# RAD_id_counter= 3190		It takes 1762.83
# RAD_id_counter= 3200		It takes 1768.32
# RAD_id_counter= 3210		It takes 1773.80
# RAD_id_counter= 3220		It takes 1779.30
# RAD_id_counter= 3230		It takes 1784.75
# RAD_id_counter= 3240		It takes 1790.27
# RAD_id_counter= 3250		It takes 1795.77
# RAD_id_counter= 3260		It takes 1801.23
# RAD_id_counter= 3270		It takes 1806.77
# RAD_id_counter= 3280		It takes 1812.32
# RAD_id_counter= 3290		It takes 1817.81
# RAD_id_counter= 3300		It takes 1823.27
# RAD_id_counter= 3310		It takes 1828.79
# RAD_id_counter= 3320		It takes 1834.33
# RAD_id_counter= 3330		It takes 1839.83
# RAD_id_counter= 3340		It takes 1845.31
# RAD_id_counter= 3350		It takes 1850.81
# RAD_id_counter= 3360		It takes 1856.30
# RAD_id_counter= 3370		It takes 1861.76
# RAD_id_counter= 3380		It takes 1867.23
# RAD_id_counter= 3390		It takes 1872.73
# RAD_id_counter= 3400		It takes 1878.28
# RAD_id_counter= 3410		It takes 1883.76
# RAD_id_counter= 3420		It takes 1889.20
# RAD_id_counter= 3430		It takes 1894.67
# RAD_id_counter= 3440		It takes 1900.17
# RAD_id_counter= 3450		It takes 1905.65
# RAD_id_counter= 3460		It takes 1911.15
# RAD_id_counter= 3470		It takes 1916.62
# RAD_id_counter= 3480		It takes 1922.16
# RAD_id_counter= 3490		It takes 1927.68
# RAD_id_counter= 3500		It takes 1933.20
# RAD_id_counter= 3510		It takes 1938.71
# RAD_id_counter= 3520		It takes 1944.16
# RAD_id_counter= 3530		It takes 1949.65
# RAD_id_counter= 3540		It takes 1955.16
# RAD_id_counter= 3550		It takes 1960.62
# RAD_id_counter= 3560		It takes 1966.13
# RAD_id_counter= 3570		It takes 1971.60
# RAD_id_counter= 3580		It takes 1977.13
# RAD_id_counter= 3590		It takes 1982.64
# RAD_id_counter= 3600		It takes 1988.08
# RAD_id_counter= 3610		It takes 1993.57
# RAD_id_counter= 3620		It takes 1999.07
# RAD_id_counter= 3630		It takes 2004.49
# RAD_id_counter= 3640		It takes 2009.95
# RAD_id_counter= 3650		It takes 2015.44
# RAD_id_counter= 3660		It takes 2020.90
# RAD_id_counter= 3670		It takes 2026.37
# RAD_id_counter= 3680		It takes 2031.89
# RAD_id_counter= 3690		It takes 2037.42
# RAD_id_counter= 3700		It takes 2042.86
# RAD_id_counter= 3710		It takes 2048.34
# RAD_id_counter= 3720		It takes 2053.84
# RAD_id_counter= 3730		It takes 2059.33
# RAD_id_counter= 3740		It takes 2064.84
# RAD_id_counter= 3750		It takes 2070.25
# RAD_id_counter= 3760		It takes 2075.70
# RAD_id_counter= 3770		It takes 2081.15
# RAD_id_counter= 3780		It takes 2086.71
# RAD_id_counter= 3790		It takes 2092.28
# RAD_id_counter= 3800		It takes 2097.77
# RAD_id_counter= 3810		It takes 2103.27
# RAD_id_counter= 3820		It takes 2108.83
# RAD_id_counter= 3830		It takes 2114.31
# RAD_id_counter= 3840		It takes 2119.81
# RAD_id_counter= 3850		It takes 2125.33
# RAD_id_counter= 3860		It takes 2130.89
# RAD_id_counter= 3870		It takes 2136.37
# RAD_id_counter= 3880		It takes 2141.88
# RAD_id_counter= 3890		It takes 2147.37
# RAD_id_counter= 3900		It takes 2152.86
# RAD_id_counter= 3910		It takes 2158.35
# RAD_id_counter= 3920		It takes 2163.88
# RAD_id_counter= 3930		It takes 2169.36
# RAD_id_counter= 3940		It takes 2174.82
# RAD_id_counter= 3950		It takes 2180.30
# RAD_id_counter= 3960		It takes 2185.76
# RAD_id_counter= 3970		It takes 2191.26
# RAD_id_counter= 3980		It takes 2196.76
# RAD_id_counter= 3990		It takes 2202.21
# RAD_id_counter= 4000		It takes 2207.73
# RAD_id_counter= 4010		It takes 2213.20
# RAD_id_counter= 4020		It takes 2218.71
# RAD_id_counter= 4030		It takes 2224.22
# RAD_id_counter= 4040		It takes 2229.74
# RAD_id_counter= 4050		It takes 2235.25
# RAD_id_counter= 4060		It takes 2240.77
# RAD_id_counter= 4070		It takes 2246.31
# RAD_id_counter= 4080		It takes 2251.75
# RAD_id_counter= 4090		It takes 2257.22
# RAD_id_counter= 4100		It takes 2262.73
# RAD_id_counter= 4110		It takes 2268.23
# RAD_id_counter= 4120		It takes 2273.75
# RAD_id_counter= 4130		It takes 2279.21
# RAD_id_counter= 4140		It takes 2284.68
# RAD_id_counter= 4150		It takes 2290.17
# RAD_id_counter= 4160		It takes 2295.64
# RAD_id_counter= 4170		It takes 2301.14
# RAD_id_counter= 4180		It takes 2306.58
# RAD_id_counter= 4190		It takes 2312.12
# RAD_id_counter= 4200		It takes 2317.65
# RAD_id_counter= 4210		It takes 2323.15
# RAD_id_counter= 4220		It takes 2328.58
# RAD_id_counter= 4230		It takes 2334.14
# RAD_id_counter= 4240		It takes 2339.59
# RAD_id_counter= 4250		It takes 2345.02
# RAD_id_counter= 4260		It takes 2350.49
# RAD_id_counter= 4270		It takes 2355.92
# RAD_id_counter= 4280		It takes 2361.41
# RAD_id_counter= 4290		It takes 2366.92
# RAD_id_counter= 4300		It takes 2372.38
# RAD_id_counter= 4310		It takes 2377.81
# RAD_id_counter= 4320		It takes 2383.30
# RAD_id_counter= 4330		It takes 2388.81
# RAD_id_counter= 4340		It takes 2394.27
# RAD_id_counter= 4350		It takes 2399.82
# RAD_id_counter= 4360		It takes 2405.35
# RAD_id_counter= 4370		It takes 2410.81
# RAD_id_counter= 4380		It takes 2416.26
# RAD_id_counter= 4390		It takes 2421.76
# RAD_id_counter= 4400		It takes 2427.22
# RAD_id_counter= 4410		It takes 2432.68
# RAD_id_counter= 4420		It takes 2438.14
# RAD_id_counter= 4430		It takes 2443.62
# RAD_id_counter= 4440		It takes 2449.13
# RAD_id_counter= 4450		It takes 2454.63
# RAD_id_counter= 4460		It takes 2460.16
# RAD_id_counter= 4470		It takes 2465.63
# RAD_id_counter= 4480		It takes 2471.12
# RAD_id_counter= 4490		It takes 2476.62
# RAD_id_counter= 4500		It takes 2482.07
# RAD_id_counter= 4510		It takes 2487.50
# RAD_id_counter= 4520		It takes 2493.01
# RAD_id_counter= 4530		It takes 2498.49
# RAD_id_counter= 4540		It takes 2504.00
# RAD_id_counter= 4550		It takes 2509.51
# RAD_id_counter= 4560		It takes 2514.97
# RAD_id_counter= 4570		It takes 2520.41
# RAD_id_counter= 4580		It takes 2525.91
# RAD_id_counter= 4590		It takes 2531.36
# RAD_id_counter= 4600		It takes 2536.82
# RAD_id_counter= 4610		It takes 2542.26
# RAD_id_counter= 4620		It takes 2547.78
# RAD_id_counter= 4630		It takes 2553.31
# RAD_id_counter= 4640		It takes 2558.78
# RAD_id_counter= 4650		It takes 2564.22
# RAD_id_counter= 4660		It takes 2569.64
# RAD_id_counter= 4670		It takes 2575.12
# RAD_id_counter= 4680		It takes 2580.56
# RAD_id_counter= 4690		It takes 2586.06
# RAD_id_counter= 4700		It takes 2591.51
# RAD_id_counter= 4710		It takes 2597.02
# RAD_id_counter= 4720		It takes 2602.49
# RAD_id_counter= 4730		It takes 2607.96
# RAD_id_counter= 4740		It takes 2613.43
# RAD_id_counter= 4750		It takes 2618.94
# RAD_id_counter= 4760		It takes 2624.44
# RAD_id_counter= 4770		It takes 2629.90
# RAD_id_counter= 4780		It takes 2635.44
# RAD_id_counter= 4790		It takes 2640.85
# RAD_id_counter= 4800		It takes 2646.32
# RAD_id_counter= 4810		It takes 2651.81
# RAD_id_counter= 4820		It takes 2657.32
# RAD_id_counter= 4830		It takes 2662.80
# RAD_id_counter= 4840		It takes 2668.24
# RAD_id_counter= 4850		It takes 2673.79
# RAD_id_counter= 4860		It takes 2679.23
# RAD_id_counter= 4870		It takes 2684.70
# RAD_id_counter= 4880		It takes 2690.18
# RAD_id_counter= 4890		It takes 2695.65
# RAD_id_counter= 4900		It takes 2701.12
# RAD_id_counter= 4910		It takes 2706.66
# RAD_id_counter= 4920		It takes 2712.11
# RAD_id_counter= 4930		It takes 2717.59
# RAD_id_counter= 4940		It takes 2723.06
# RAD_id_counter= 4950		It takes 2728.57
# RAD_id_counter= 4960		It takes 2734.11
# RAD_id_counter= 4970		It takes 2739.67
# RAD_id_counter= 4980		It takes 2745.16
# RAD_id_counter= 4990		It takes 2750.61
# RAD_id_counter= 5000		It takes 2756.09
# RAD_id_counter= 5010		It takes 2761.61
# RAD_id_counter= 5020		It takes 2767.10
# RAD_id_counter= 5030		It takes 2772.54
# RAD_id_counter= 5040		It takes 2778.01
# RAD_id_counter= 5050		It takes 2783.46
# RAD_id_counter= 5060		It takes 2789.04
# RAD_id_counter= 5070		It takes 2794.56
# RAD_id_counter= 5080		It takes 2800.05
# RAD_id_counter= 5090		It takes 2805.54
# RAD_id_counter= 5100		It takes 2811.05
# RAD_id_counter= 5110		It takes 2816.56
# RAD_id_counter= 5120		It takes 2822.11
# RAD_id_counter= 5130		It takes 2827.57
# RAD_id_counter= 5140		It takes 2833.10
# RAD_id_counter= 5150		It takes 2838.58
# RAD_id_counter= 5160		It takes 2844.07
# RAD_id_counter= 5170		It takes 2849.58
# RAD_id_counter= 5180		It takes 2855.07
# RAD_id_counter= 5190		It takes 2860.58
# RAD_id_counter= 5200		It takes 2866.03
# RAD_id_counter= 5210		It takes 2871.48
# RAD_id_counter= 5220		It takes 2877.03
# RAD_id_counter= 5230		It takes 2882.54
# RAD_id_counter= 5240		It takes 2888.00
# RAD_id_counter= 5250		It takes 2893.51
# RAD_id_counter= 5260		It takes 2899.05
# RAD_id_counter= 5270		It takes 2904.56
# RAD_id_counter= 5280		It takes 2910.01
# RAD_id_counter= 5290		It takes 2915.53
# RAD_id_counter= 5300		It takes 2921.06
# RAD_id_counter= 5310		It takes 2926.56
# RAD_id_counter= 5320		It takes 2932.09
# RAD_id_counter= 5330		It takes 2937.59
# RAD_id_counter= 5340		It takes 2943.15
# RAD_id_counter= 5350		It takes 2948.65
# RAD_id_counter= 5360		It takes 2954.18
# RAD_id_counter= 5370		It takes 2959.67
# RAD_id_counter= 5380		It takes 2965.21
# RAD_id_counter= 5390		It takes 2970.73
# RAD_id_counter= 5400		It takes 2976.19
# RAD_id_counter= 5410		It takes 2981.67
# RAD_id_counter= 5420		It takes 2987.22
# RAD_id_counter= 5430		It takes 2992.68
# RAD_id_counter= 5440		It takes 2998.20
# RAD_id_counter= 5450		It takes 3003.66
# RAD_id_counter= 5460		It takes 3009.13
# RAD_id_counter= 5470		It takes 3014.58
# RAD_id_counter= 5480		It takes 3020.09
# RAD_id_counter= 5490		It takes 3025.59
# RAD_id_counter= 5500		It takes 3031.06
# RAD_id_counter= 5510		It takes 3036.55
# RAD_id_counter= 5520		It takes 3042.01
# RAD_id_counter= 5530		It takes 3047.56
# RAD_id_counter= 5540		It takes 3053.05
# RAD_id_counter= 5550		It takes 3058.52
# RAD_id_counter= 5560		It takes 3064.00
# RAD_id_counter= 5570		It takes 3069.46
# RAD_id_counter= 5580		It takes 3074.97
# RAD_id_counter= 5590		It takes 3080.49
# RAD_id_counter= 5600		It takes 3085.96
# RAD_id_counter= 5610		It takes 3091.44
# RAD_id_counter= 5620		It takes 3096.94
# RAD_id_counter= 5630		It takes 3102.41
# RAD_id_counter= 5640		It takes 3107.96
# RAD_id_counter= 5650		It takes 3113.47
# RAD_id_counter= 5660		It takes 3119.00
# RAD_id_counter= 5670		It takes 3124.54
# RAD_id_counter= 5680		It takes 3130.05
# RAD_id_counter= 5690		It takes 3135.54
# RAD_id_counter= 5700		It takes 3141.01
# RAD_id_counter= 5710		It takes 3146.52
# RAD_id_counter= 5720		It takes 3152.05
# RAD_id_counter= 5730		It takes 3157.56
# RAD_id_counter= 5740		It takes 3163.06
# RAD_id_counter= 5750		It takes 3168.57
# RAD_id_counter= 5760		It takes 3174.06
# RAD_id_counter= 5770		It takes 3179.59
# RAD_id_counter= 5780		It takes 3185.08
# RAD_id_counter= 5790		It takes 3190.55
# RAD_id_counter= 5800		It takes 3196.09
# RAD_id_counter= 5810		It takes 3201.64
# RAD_id_counter= 5820		It takes 3207.10
# RAD_id_counter= 5830		It takes 3212.60
# RAD_id_counter= 5840		It takes 3218.10
# RAD_id_counter= 5850		It takes 3223.60
# RAD_id_counter= 5860		It takes 3229.11
# RAD_id_counter= 5870		It takes 3234.60
# RAD_id_counter= 5880		It takes 3240.13
# RAD_id_counter= 5890		It takes 3245.58
# RAD_id_counter= 5900		It takes 3251.09
# RAD_id_counter= 5910		It takes 3256.55
# RAD_id_counter= 5920		It takes 3262.09
# RAD_id_counter= 5930		It takes 3267.60
# RAD_id_counter= 5940		It takes 3273.05
# RAD_id_counter= 5950		It takes 3278.54
# RAD_id_counter= 5960		It takes 3284.06
# RAD_id_counter= 5970		It takes 3289.57
# RAD_id_counter= 5980		It takes 3295.04
# RAD_id_counter= 5990		It takes 3300.57
# RAD_id_counter= 6000		It takes 3306.09
# RAD_id_counter= 6010		It takes 3311.64
# RAD_id_counter= 6020		It takes 3317.11
# RAD_id_counter= 6030		It takes 3322.62
# RAD_id_counter= 6040		It takes 3328.10
# RAD_id_counter= 6050		It takes 3333.65
# RAD_id_counter= 6060		It takes 3339.16
# RAD_id_counter= 6070		It takes 3344.67
# RAD_id_counter= 6080		It takes 3350.17
# RAD_id_counter= 6090		It takes 3355.64
# RAD_id_counter= 6100		It takes 3361.15
# RAD_id_counter= 6110		It takes 3366.69
# RAD_id_counter= 6120		It takes 3372.18
# RAD_id_counter= 6130		It takes 3377.68
# RAD_id_counter= 6140		It takes 3383.19
# RAD_id_counter= 6150		It takes 3388.73
# RAD_id_counter= 6160		It takes 3394.18
# RAD_id_counter= 6170		It takes 3399.71
# RAD_id_counter= 6180		It takes 3405.22
# RAD_id_counter= 6190		It takes 3410.73
# RAD_id_counter= 6200		It takes 3416.23
# RAD_id_counter= 6210		It takes 3421.70
# RAD_id_counter= 6220		It takes 3427.19
# RAD_id_counter= 6230		It takes 3432.62
# RAD_id_counter= 6240		It takes 3438.08
# RAD_id_counter= 6250		It takes 3443.57
# RAD_id_counter= 6260		It takes 3449.07
# RAD_id_counter= 6270		It takes 3454.53
# RAD_id_counter= 6280		It takes 3460.00
# RAD_id_counter= 6290		It takes 3465.47
# RAD_id_counter= 6300		It takes 3470.96
# RAD_id_counter= 6310		It takes 3476.44
# RAD_id_counter= 6320		It takes 3481.97
# RAD_id_counter= 6330		It takes 3487.41
# RAD_id_counter= 6340		It takes 3492.86
# RAD_id_counter= 6350		It takes 3498.36
# RAD_id_counter= 6360		It takes 3503.81
# RAD_id_counter= 6370		It takes 3509.30
# RAD_id_counter= 6380		It takes 3514.88
# RAD_id_counter= 6390		It takes 3520.37
# RAD_id_counter= 6400		It takes 3525.87
# RAD_id_counter= 6410		It takes 3531.37
# RAD_id_counter= 6420		It takes 3536.90
# RAD_id_counter= 6430		It takes 3542.40
# RAD_id_counter= 6440		It takes 3547.90
# RAD_id_counter= 6450		It takes 3553.44
# RAD_id_counter= 6460		It takes 3558.94
# RAD_id_counter= 6470		It takes 3564.46
# RAD_id_counter= 6480		It takes 3569.97
# RAD_id_counter= 6490		It takes 3575.51
# RAD_id_counter= 6500		It takes 3580.97
# RAD_id_counter= 6510		It takes 3586.46
# RAD_id_counter= 6520		It takes 3591.88
# RAD_id_counter= 6530		It takes 3597.35
# RAD_id_counter= 6540		It takes 3602.85
# RAD_id_counter= 6550		It takes 3608.31
# RAD_id_counter= 6560		It takes 3613.79
# RAD_id_counter= 6570		It takes 3619.28
# RAD_id_counter= 6580		It takes 3624.72
# RAD_id_counter= 6590		It takes 3630.20
# RAD_id_counter= 6600		It takes 3635.67
# RAD_id_counter= 6610		It takes 3641.13
# RAD_id_counter= 6620		It takes 3646.61
# RAD_id_counter= 6630		It takes 3652.13
# RAD_id_counter= 6640		It takes 3657.59
# RAD_id_counter= 6650		It takes 3663.07
# RAD_id_counter= 6660		It takes 3668.58
# RAD_id_counter= 6670		It takes 3674.05
# RAD_id_counter= 6680		It takes 3679.50
# RAD_id_counter= 6690		It takes 3685.01
# RAD_id_counter= 6700		It takes 3690.53
# RAD_id_counter= 6710		It takes 3696.03
# RAD_id_counter= 6720		It takes 3701.54
# RAD_id_counter= 6730		It takes 3707.01
# RAD_id_counter= 6740		It takes 3712.48
# RAD_id_counter= 6750		It takes 3718.04
# RAD_id_counter= 6760		It takes 3723.55
# RAD_id_counter= 6770		It takes 3729.02
# RAD_id_counter= 6780		It takes 3734.52
# RAD_id_counter= 6790		It takes 3740.05
# RAD_id_counter= 6800		It takes 3745.51
# RAD_id_counter= 6810		It takes 3750.98
# RAD_id_counter= 6820		It takes 3756.45
# RAD_id_counter= 6830		It takes 3761.99
# RAD_id_counter= 6840		It takes 3767.43
# RAD_id_counter= 6850		It takes 3772.92
# RAD_id_counter= 6860		It takes 3778.35
# RAD_id_counter= 6870		It takes 3783.81
# RAD_id_counter= 6880		It takes 3789.26
# RAD_id_counter= 6890		It takes 3794.74
# RAD_id_counter= 6900		It takes 3800.20
# RAD_id_counter= 6910		It takes 3805.71
# RAD_id_counter= 6920		It takes 3811.20
# RAD_id_counter= 6930		It takes 3816.69
# RAD_id_counter= 6940		It takes 3822.18
# RAD_id_counter= 6950		It takes 3827.69
# RAD_id_counter= 6960		It takes 3833.17
# RAD_id_counter= 6970		It takes 3838.59
# RAD_id_counter= 6980		It takes 3844.07
# RAD_id_counter= 6990		It takes 3849.52
# RAD_id_counter= 7000		It takes 3855.01
# RAD_id_counter= 7010		It takes 3860.50
# RAD_id_counter= 7020		It takes 3865.97
# RAD_id_counter= 7030		It takes 3871.39
# RAD_id_counter= 7040		It takes 3876.89
# RAD_id_counter= 7050		It takes 3882.40
# RAD_id_counter= 7060		It takes 3887.89
# RAD_id_counter= 7070		It takes 3893.39
# RAD_id_counter= 7080		It takes 3898.87
# RAD_id_counter= 7090		It takes 3904.31
# RAD_id_counter= 7100		It takes 3909.83
# RAD_id_counter= 7110		It takes 3915.33
# RAD_id_counter= 7120		It takes 3920.73
# RAD_id_counter= 7130		It takes 3926.26
# RAD_id_counter= 7140		It takes 3931.72
# RAD_id_counter= 7150		It takes 3937.21
# RAD_id_counter= 7160		It takes 3942.67
# RAD_id_counter= 7170		It takes 3948.19
# RAD_id_counter= 7180		It takes 3953.64
# RAD_id_counter= 7190		It takes 3959.13
# RAD_id_counter= 7200		It takes 3964.65
# RAD_id_counter= 7210		It takes 3970.14
# RAD_id_counter= 7220		It takes 3975.60
# RAD_id_counter= 7230		It takes 3981.13
# RAD_id_counter= 7240		It takes 3986.62
# RAD_id_counter= 7250		It takes 3992.09
# RAD_id_counter= 7260		It takes 3997.57
# RAD_id_counter= 7270		It takes 4003.04
# RAD_id_counter= 7280		It takes 4008.50
# RAD_id_counter= 7290		It takes 4013.99
# RAD_id_counter= 7300		It takes 4019.45
# RAD_id_counter= 7310		It takes 4025.00
# RAD_id_counter= 7320		It takes 4030.52
# RAD_id_counter= 7330		It takes 4036.01
# RAD_id_counter= 7340		It takes 4041.50
# RAD_id_counter= 7350		It takes 4046.99
# RAD_id_counter= 7360		It takes 4052.47
# RAD_id_counter= 7370		It takes 4057.93
# RAD_id_counter= 7380		It takes 4063.41
# RAD_id_counter= 7390		It takes 4068.92
# RAD_id_counter= 7400		It takes 4074.38
# RAD_id_counter= 7410		It takes 4079.87
# RAD_id_counter= 7420		It takes 4085.34
# RAD_id_counter= 7430		It takes 4090.79
# RAD_id_counter= 7440		It takes 4096.24
# RAD_id_counter= 7450		It takes 4101.68
# RAD_id_counter= 7460		It takes 4107.15
# RAD_id_counter= 7470		It takes 4112.59
# RAD_id_counter= 7480		It takes 4118.08
# RAD_id_counter= 7490		It takes 4123.64
# RAD_id_counter= 7500		It takes 4129.14
# RAD_id_counter= 7510		It takes 4134.63
# RAD_id_counter= 7520		It takes 4140.14
# RAD_id_counter= 7530		It takes 4145.62
# RAD_id_counter= 7540		It takes 4151.09
# RAD_id_counter= 7550		It takes 4156.54
# RAD_id_counter= 7560		It takes 4162.11
# RAD_id_counter= 7570		It takes 4167.58
# RAD_id_counter= 7580		It takes 4173.02
# RAD_id_counter= 7590		It takes 4178.48
# RAD_id_counter= 7600		It takes 4183.92
# RAD_id_counter= 7610		It takes 4189.40
# RAD_id_counter= 7620		It takes 4194.87
# RAD_id_counter= 7630		It takes 4200.40
# RAD_id_counter= 7640		It takes 4205.87
# RAD_id_counter= 7650		It takes 4211.43
# RAD_id_counter= 7660		It takes 4216.93
# RAD_id_counter= 7670		It takes 4222.48
# RAD_id_counter= 7680		It takes 4227.94
# RAD_id_counter= 7690		It takes 4233.41
# RAD_id_counter= 7700		It takes 4238.91
# RAD_id_counter= 7710		It takes 4244.38
# RAD_id_counter= 7720		It takes 4249.82
# RAD_id_counter= 7730		It takes 4255.31
# RAD_id_counter= 7740		It takes 4260.77
# RAD_id_counter= 7750		It takes 4266.23
# RAD_id_counter= 7760		It takes 4271.75
# RAD_id_counter= 7770		It takes 4277.24
# RAD_id_counter= 7780		It takes 4282.73
# RAD_id_counter= 7790		It takes 4288.28
# RAD_id_counter= 7800		It takes 4293.75
# RAD_id_counter= 7810		It takes 4299.26
# RAD_id_counter= 7820		It takes 4304.71
# RAD_id_counter= 7830		It takes 4310.18
# RAD_id_counter= 7840		It takes 4315.69
# RAD_id_counter= 7850		It takes 4321.22
# RAD_id_counter= 7860		It takes 4326.72
# RAD_id_counter= 7870		It takes 4332.16
# RAD_id_counter= 7880		It takes 4337.63
# RAD_id_counter= 7890		It takes 4343.09
# RAD_id_counter= 7900		It takes 4348.60
# RAD_id_counter= 7910		It takes 4354.11
# RAD_id_counter= 7920		It takes 4359.59
# RAD_id_counter= 7930		It takes 4365.04
# RAD_id_counter= 7940		It takes 4370.62
# RAD_id_counter= 7950		It takes 4376.13
# RAD_id_counter= 7960		It takes 4381.57
# RAD_id_counter= 7970		It takes 4387.02
# RAD_id_counter= 7980		It takes 4392.50
# RAD_id_counter= 7990		It takes 4398.00
# RAD_id_counter= 8000		It takes 4403.54
# RAD_id_counter= 8010		It takes 4408.97
# RAD_id_counter= 8020		It takes 4414.44
# RAD_id_counter= 8030		It takes 4419.92
# RAD_id_counter= 8040		It takes 4425.40
# RAD_id_counter= 8050		It takes 4430.89
# RAD_id_counter= 8060		It takes 4436.47
# RAD_id_counter= 8070		It takes 4441.91
# RAD_id_counter= 8080		It takes 4447.37
# RAD_id_counter= 8090		It takes 4452.88
# RAD_id_counter= 8100		It takes 4458.37
# RAD_id_counter= 8110		It takes 4463.87
# RAD_id_counter= 8120		It takes 4469.38
# RAD_id_counter= 8130		It takes 4474.86
# RAD_id_counter= 8140		It takes 4480.40
# RAD_id_counter= 8150		It takes 4485.84
# RAD_id_counter= 8160		It takes 4491.37
# RAD_id_counter= 8170		It takes 4496.86
# RAD_id_counter= 8180		It takes 4502.41
# RAD_id_counter= 8190		It takes 4507.87
# RAD_id_counter= 8200		It takes 4513.37
# RAD_id_counter= 8210		It takes 4518.84
# RAD_id_counter= 8220		It takes 4524.34
# RAD_id_counter= 8230		It takes 4529.84
# RAD_id_counter= 8240		It takes 4535.33
# RAD_id_counter= 8250		It takes 4540.81
# RAD_id_counter= 8260		It takes 4546.26
# RAD_id_counter= 8270		It takes 4551.72
# RAD_id_counter= 8280		It takes 4557.24
# RAD_id_counter= 8290		It takes 4562.73
# RAD_id_counter= 8300		It takes 4568.30
# RAD_id_counter= 8310		It takes 4573.82
# RAD_id_counter= 8320		It takes 4579.29
# RAD_id_counter= 8330		It takes 4584.81
# RAD_id_counter= 8340		It takes 4590.34
# RAD_id_counter= 8350		It takes 4595.82
# RAD_id_counter= 8360		It takes 4601.29
# RAD_id_counter= 8370		It takes 4606.78
# RAD_id_counter= 8380		It takes 4612.24
# RAD_id_counter= 8390		It takes 4617.79
# RAD_id_counter= 8400		It takes 4623.30
# RAD_id_counter= 8410		It takes 4628.82
# RAD_id_counter= 8420		It takes 4634.32
# RAD_id_counter= 8430		It takes 4639.76
# RAD_id_counter= 8440		It takes 4645.23
# RAD_id_counter= 8450		It takes 4650.74
# RAD_id_counter= 8460		It takes 4656.20
# RAD_id_counter= 8470		It takes 4661.70
# RAD_id_counter= 8480		It takes 4667.22
# RAD_id_counter= 8490		It takes 4672.73
# RAD_id_counter= 8500		It takes 4678.29
# RAD_id_counter= 8510		It takes 4683.80
# RAD_id_counter= 8520		It takes 4689.26
# RAD_id_counter= 8530		It takes 4694.78
# RAD_id_counter= 8540		It takes 4700.31
# RAD_id_counter= 8550		It takes 4705.81
# RAD_id_counter= 8560		It takes 4711.31
# RAD_id_counter= 8570		It takes 4716.78
# RAD_id_counter= 8580		It takes 4722.26
# RAD_id_counter= 8590		It takes 4727.78
# RAD_id_counter= 8600		It takes 4733.32
# RAD_id_counter= 8610		It takes 4738.84
# RAD_id_counter= 8620		It takes 4744.32
# RAD_id_counter= 8630		It takes 4749.81
# RAD_id_counter= 8640		It takes 4755.31
# RAD_id_counter= 8650		It takes 4760.79
# RAD_id_counter= 8660		It takes 4766.34
# RAD_id_counter= 8670		It takes 4771.81
# RAD_id_counter= 8680		It takes 4777.32
# RAD_id_counter= 8690		It takes 4782.83
# RAD_id_counter= 8700		It takes 4788.36
# RAD_id_counter= 8710		It takes 4793.93
# RAD_id_counter= 8720		It takes 4799.41
# RAD_id_counter= 8730		It takes 4804.93
# RAD_id_counter= 8740		It takes 4810.40
# RAD_id_counter= 8750		It takes 4815.89
# RAD_id_counter= 8760		It takes 4821.38
# RAD_id_counter= 8770		It takes 4826.86
# RAD_id_counter= 8780		It takes 4832.35
# RAD_id_counter= 8790		It takes 4837.86
# RAD_id_counter= 8800		It takes 4843.39
# RAD_id_counter= 8810		It takes 4848.98
# RAD_id_counter= 8820		It takes 4854.50
# RAD_id_counter= 8830		It takes 4859.99
# RAD_id_counter= 8840		It takes 4865.48
# RAD_id_counter= 8850		It takes 4871.01
# RAD_id_counter= 8860		It takes 4876.50
# RAD_id_counter= 8870		It takes 4881.96
# RAD_id_counter= 8880		It takes 4887.48
# RAD_id_counter= 8890		It takes 4892.97
# RAD_id_counter= 8900		It takes 4898.45
# RAD_id_counter= 8910		It takes 4903.94
# RAD_id_counter= 8920		It takes 4909.40
# RAD_id_counter= 8930		It takes 4914.86
# RAD_id_counter= 8940		It takes 4920.31
# RAD_id_counter= 8950		It takes 4925.78
# RAD_id_counter= 8960		It takes 4931.34
# RAD_id_counter= 8970		It takes 4936.78
# RAD_id_counter= 8980		It takes 4942.28
# RAD_id_counter= 8990		It takes 4947.80
# RAD_id_counter= 9000		It takes 4953.27
# RAD_id_counter= 9010		It takes 4958.74
# RAD_id_counter= 9020		It takes 4964.20
# RAD_id_counter= 9030		It takes 4969.66
# RAD_id_counter= 9040		It takes 4975.11
# RAD_id_counter= 9050		It takes 4980.62
# RAD_id_counter= 9060		It takes 4986.06
# RAD_id_counter= 9070		It takes 4991.55
# RAD_id_counter= 9080		It takes 4997.05
# RAD_id_counter= 9090		It takes 5002.52
# RAD_id_counter= 9100		It takes 5008.00
# RAD_id_counter= 9110		It takes 5013.45
# RAD_id_counter= 9120		It takes 5018.94
# RAD_id_counter= 9130		It takes 5024.40
# RAD_id_counter= 9140		It takes 5029.79
# RAD_id_counter= 9150		It takes 5035.29
# RAD_id_counter= 9160		It takes 5040.83
# RAD_id_counter= 9170		It takes 5046.34
# RAD_id_counter= 9180		It takes 5051.86
# RAD_id_counter= 9190		It takes 5057.36
# RAD_id_counter= 9200		It takes 5062.86
# RAD_id_counter= 9210		It takes 5068.36
# RAD_id_counter= 9220		It takes 5073.83
# RAD_id_counter= 9230		It takes 5079.29
# RAD_id_counter= 9240		It takes 5084.80
# RAD_id_counter= 9250		It takes 5090.34
# RAD_id_counter= 9260		It takes 5095.82
# RAD_id_counter= 9270		It takes 5101.27
# RAD_id_counter= 9280		It takes 5106.78
# RAD_id_counter= 9290		It takes 5112.24
# RAD_id_counter= 9300		It takes 5117.71
# RAD_id_counter= 9310		It takes 5123.18
# RAD_id_counter= 9320		It takes 5128.63
# RAD_id_counter= 9330		It takes 5134.14
# RAD_id_counter= 9340		It takes 5139.68
# RAD_id_counter= 9350		It takes 5145.16
# RAD_id_counter= 9360		It takes 5150.59
# RAD_id_counter= 9370		It takes 5156.02
# RAD_id_counter= 9380		It takes 5161.52
# RAD_id_counter= 9390		It takes 5166.96
# RAD_id_counter= 9400		It takes 5172.43
# RAD_id_counter= 9410		It takes 5177.93
# RAD_id_counter= 9420		It takes 5183.38
# RAD_id_counter= 9430		It takes 5188.86
# RAD_id_counter= 9440		It takes 5194.31
# RAD_id_counter= 9450		It takes 5199.78
# RAD_id_counter= 9460		It takes 5205.24
# RAD_id_counter= 9470		It takes 5210.72
# RAD_id_counter= 9480		It takes 5216.21
# RAD_id_counter= 9490		It takes 5221.64
# RAD_id_counter= 9500		It takes 5227.11
# RAD_id_counter= 9510		It takes 5232.59
# RAD_id_counter= 9520		It takes 5238.05
# RAD_id_counter= 9530		It takes 5243.47
# RAD_id_counter= 9540		It takes 5248.99
# RAD_id_counter= 9550		It takes 5254.45
# RAD_id_counter= 9560		It takes 5260.00
# RAD_id_counter= 9570		It takes 5265.46
# RAD_id_counter= 9580		It takes 5270.93
# RAD_id_counter= 9590		It takes 5276.45
# RAD_id_counter= 9600		It takes 5281.97
# RAD_id_counter= 9610		It takes 5287.43
# RAD_id_counter= 9620		It takes 5292.96
# RAD_id_counter= 9630		It takes 5298.45
# RAD_id_counter= 9640		It takes 5303.92
# RAD_id_counter= 9650		It takes 5309.37
# RAD_id_counter= 9660		It takes 5314.92
# RAD_id_counter= 9670		It takes 5320.39
# RAD_id_counter= 9680		It takes 5325.89
# RAD_id_counter= 9690		It takes 5331.41
# RAD_id_counter= 9700		It takes 5336.93
# RAD_id_counter= 9710		It takes 5342.43
# RAD_id_counter= 9720		It takes 5347.91
# RAD_id_counter= 9730		It takes 5353.40
# RAD_id_counter= 9740		It takes 5358.90
# RAD_id_counter= 9750		It takes 5364.42
# RAD_id_counter= 9760		It takes 5369.94
# RAD_id_counter= 9770		It takes 5375.42
# RAD_id_counter= 9780		It takes 5380.93
# RAD_id_counter= 9790		It takes 5386.48
# RAD_id_counter= 9800		It takes 5391.97
# RAD_id_counter= 9810		It takes 5397.47
# RAD_id_counter= 9820		It takes 5402.93
# RAD_id_counter= 9830		It takes 5408.42
# RAD_id_counter= 9840		It takes 5413.90
# RAD_id_counter= 9850		It takes 5419.38
# RAD_id_counter= 9860		It takes 5424.91
# RAD_id_counter= 9870		It takes 5430.43
# RAD_id_counter= 9880		It takes 5435.89
# RAD_id_counter= 9890		It takes 5441.37
# RAD_id_counter= 9900		It takes 5446.83
# RAD_id_counter= 9910		It takes 5452.32
# RAD_id_counter= 9920		It takes 5457.82
# RAD_id_counter= 9930		It takes 5463.31
# RAD_id_counter= 9940		It takes 5468.78
# RAD_id_counter= 9950		It takes 5474.29
# RAD_id_counter= 9960		It takes 5479.83
# RAD_id_counter= 9970		It takes 5485.39
# RAD_id_counter= 9980		It takes 5490.86
# RAD_id_counter= 9990		It takes 5496.36
# It took  01:31:41
# end time: 2018-09-07 03:56:03

# %% [markdown]
# ```bash
# zip -r "SRAD2018_submit_Neutrino_PredNet_v0.3.2.0_18.09.01.14.07.zip" "SRAD2018_submit_Neutrino_PredNet_v0.3.2.0_18.09.01.14.07"
# ls | wc -l
# ```
# 18.09.02 15.50

# %%
version = 'SRAD2018_submit_Neutrino_PredNet_v0.3.1.0_18.09.01.13.38'
start_time = time.time()
print(time.strftime("start time: %Y-%m-%d %H:%M:%S", time.localtime()))
for RAD_id_counter, RAD_id in enumerate(RAD_id_submit_list[:1]):
    x = np.empty((nt, image_size, image_size, 1))
    y = np.empty((1, image_size, image_size, 1))
    for i in range(nt):
        x[i] = np.array(PIL.Image.open("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_test/%s/%s_%03d.png" % (RAD_id, RAD_id, i + 31 - nt)).resize((image_size, image_size))).astype(np.int8).reshape((image_size, image_size, 1)) / image_scalar
    x = x.reshape((1, nt, image_size, image_size, 1))
    if not os.path.exists("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_submit/%s/%s" % (version, RAD_id)):
        os.makedirs("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_submit/%s/%s" % (version, RAD_id))
    for i in range(30):
#         print('before predict %.2f' % (time.time() - start_time))
        y = test_model.predict(x)  # takes 0.2s to predict
#         print('after predict %.2f' % (time.time() - start_time))
        y = np.where(y<0.03, -0.01, y)
        for j in range(nt - 1):
            x[0][j] = x[0][j + 1]
        x[0][-1] = y[0]
        if (31 + i) % 5 == 0:
#             print('%2d:' % (31 + i))
#             print(i // 5 + 1)
            result = y[0].reshape((image_size, image_size)) * image_scalar
#             plt.imshow(result, cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
#             plt.show()
            result = result.astype(np.uint8)
            result = np.where(result==0, 255, result)
            result = PIL.Image.fromarray(result)
            result = result.resize((501, 501))
#             plt.imshow(result, cmap=cm.gist_ncar_r, vmin=vmin, vmax=vmax)
#             plt.show()
            result.save("/home/hadoop/Documents/Neutrino/SRAD2018/SRAD2018_submit/%s/%s/%s_f%03d.png" % (version, RAD_id, RAD_id, i // 5 + 1))
    if RAD_id_counter % 10 == 0:
        print('RAD_id_counter=%5d\t\tIt takes %.2f' % (RAD_id_counter, time.time() - start_time))
print(time.strftime('It took  %H:%M:%S', time.gmtime(time.time() - start_time)))
print(time.strftime("end time: %Y-%m-%d %H:%M:%S", time.localtime()))
